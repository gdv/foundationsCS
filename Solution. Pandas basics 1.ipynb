# %% [markdown]
# Read the files 2017_german_election_overall.csv and 2017_german_election_party.csv from the german-election-2017 dataset.
#
# 1.  For each area, compute the percentage of the voters over the registered voters
# 1.  For each state, compute the total number of registered voters, total votes, ...
# 1.  For each state, compute the number of votes for each party
# 1.  For each state and each party, compute the area where the party has taken the most and the least total votes
# 1.  For each state and each party, compute the area where the party has taken the most and the least votes, as a percentage of the overall registered voters.

# %%
import pandas as pd

# %%
german_party = pd.read_csv('../database/german-election-2017/2017_german_election_party.csv')

# %%
german_party.head()
# Out:
#    Unnamed: 0  area_id                          area_name               state  \
# 0           1        1              Flensburg – Schleswig  Schleswig-Holstein
# 1           2        2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2           3        3       Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3           4        4              Rendsburg-Eckernförde  Schleswig-Holstein
# 4           5        5                               Kiel  Schleswig-Holstein
#
#                                          party  votes_first_vote  \
# 0  Christlich.Demokratische.Union.Deutschlands             68102
# 1  Christlich.Demokratische.Union.Deutschlands             62260
# 2  Christlich.Demokratische.Union.Deutschlands             54812
# 3  Christlich.Demokratische.Union.Deutschlands             66625
# 4  Christlich.Demokratische.Union.Deutschlands             45691
#
#    votes_second_vote
# 0              58307
# 1              52933
# 2              47367
# ...

# %%
german_overall = pd.read_csv('../database/german-election-2017/2017_german_election_overall.csv')

# %%
german_overall.head()
# Out:
#    Unnamed: 0  area_id                         area_names               state  \
# 0           1        1              Flensburg – Schleswig  Schleswig-Holstein
# 1           2        2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2           3        3       Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3           4        4              Rendsburg-Eckernförde  Schleswig-Holstein
# 4           5        5                               Kiel  Schleswig-Holstein
#
#    registered.voters  total_votes  invalid_first_votes  invalid_second_votes  \
# 0             225659       171905                 1647                  1509
# 1             186384       139200                 1299                  1125
# 2             175950       132016                 1133                  1141
# 3             199632       157387                 1285                  1119
# 4             204650       151463                 1657                  1290
#
# ...

# %% [markdown]
# For each area, compute the percentage of the voters over the registered voters

# %%
german_overall['perc'] = german_overall['total_votes'] / german_overall['registered.voters'] * 100

# %%
german_overall.head()
# Out:
#    Unnamed: 0  area_id                         area_names               state  \
# 0           1        1              Flensburg – Schleswig  Schleswig-Holstein
# 1           2        2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2           3        3       Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3           4        4              Rendsburg-Eckernförde  Schleswig-Holstein
# 4           5        5                               Kiel  Schleswig-Holstein
#
#    registered.voters  total_votes  invalid_first_votes  invalid_second_votes  \
# 0             225659       171905                 1647                  1509
# 1             186384       139200                 1299                  1125
# 2             175950       132016                 1133                  1141
# 3             199632       157387                 1285                  1119
# 4             204650       151463                 1657                  1290
#
# ...

# %% [markdown]
# For each state, compute the total number of registered voters, total votes

# %%
states = list(set(german_overall['state']))
states
# Out:
# ['Brandenburg',
#  'Saarland',
#  'Hamburg',
#  'Nordrhein-Westfalen',
#  'Schleswig-Holstein',
#  'Hessen',
#  'Bremen',
#  'Rheinland-Pfalz',
#  'Niedersachsen',
#  'Bayern',
#  'Baden-Württemberg',
#  'Mecklenburg-Vorpommern',
#  'Sachsen',
#  'Sachsen-Anhalt',
#  'Thüringen',
#  'Berlin']

# %%
votes = {}
for state in states:
    votes[state] = sum(german_overall[german_overall['state'] == state]['total_votes'])
votes
# Out:
# {'Baden-Württemberg': 6052863,
#  'Bayern': 7440889,
#  'Berlin': 1893386,
#  'Brandenburg': 1512246,
#  'Bremen': 335380,
#  'Hamburg': 984382,
#  'Hessen': 3395511,
#  'Mecklenburg-Vorpommern': 938648,
#  'Niedersachsen': 4680872,
#  'Nordrhein-Westfalen': 9939403,
#  'Rheinland-Pfalz': 2392171,
#  'Saarland': 595341,
#  'Sachsen': 2509779,
#  'Sachsen-Anhalt': 1263412,
#  'Schleswig-Holstein': 1727460,
#  'Thüringen': 1312056}

# %%
registered = {}
for state in states:
    registered[state] = sum(german_overall[german_overall['state'] == state]['registered.voters'])
registered
# Out:
# {'Baden-Württemberg': 7732570,
#  'Bayern': 9519914,
#  'Berlin': 2503053,
#  'Brandenburg': 2051507,
#  'Bremen': 474097,
#  'Hamburg': 1296624,
#  'Hessen': 4409241,
#  'Mecklenburg-Vorpommern': 1323999,
#  'Niedersachsen': 6124125,
#  'Nordrhein-Westfalen': 13174480,
#  'Rheinland-Pfalz': 3081062,
#  'Saarland': 777263,
#  'Sachsen': 3328669,
#  'Sachsen-Anhalt': 1854982,
#  'Schleswig-Holstein': 2258129,
#  'Thüringen': 1765814}

# %% [markdown]
# For each state, compute the number of votes for each party

# %%
parties = list(set(german_party['party']))
parties
# Out:
# ['bergpartei..die.überpartei',
#  'Madgeburger.Gartenpartei',
#  'Familien.Partei.Deutschlands',
#  'Sozialdemokratische.Partei.Deutschlands',
#  'Marxistisch.Leninistische.Partei.Deutschlands',
#  'Partei.der.Vernunft',
#  'Menschliche.Welt',
#  'DIE.LINKE',
#  'Nationaldemokratische.Partei.Deutschlands',
#  'Christlich.Soziale.Union.in.Bayern.e.V.',
#  'BÜNDNIS.90.DIE.GRÜNEN',
#  'Neue.Liberale...Die.Sozialliberalen',
#  'Partei.der.Humanisten',
#  'V.Partei³...Partei.für.Veränderung..Vegetarier.und.Veganer',
#  'Mieterpartei',
#  'Deutsche.Mitte',
#  'Alternative.für.Deutschland',
#  'Bündnis.C...Christen.für.Deutschland',
#  'Die.Violetten',
#  'Ab.jetzt...Demokratie.durch.Volksabstimmung',
#  'Ökologisch.Demokratische.Partei',
#  'Die.Urbane..Eine.HipHop.Partei',
#  'Allianz.Deutscher.Demokraten',
#  'Deutsche.Kommunistische.Partei',
#  'Die.Grauen...Für.alle.Generationen',
#  'Allianz.für.Menschenrechte.Tier..und.Naturschutz',
#  'FREIE.WÄHLER',
#  'DIE.EINHEIT',
# ...

# %%
import collections
v = {}
for state in states:
    v[state] = collections.Counter()
    single_state = german_party[german_party.state == state]
    for party in list(set(single_state['party'])):
        v[state][party] = sum(single_state[single_state.party == party]['votes_first_vote'])
v
# Out:
# {'Baden-Württemberg': Counter({'Ab.jetzt...Demokratie.durch.Volksabstimmung': 0,
#           'Allianz.Deutscher.Demokraten': 0,
#           'Allianz.für.Menschenrechte.Tier..und.Naturschutz': 0,
#           'Alternative.für.Deutschland': 689893,
#           'Bayernpartei': 0,
#           'BÜNDNIS.90.DIE.GRÜNEN': 801603,
#           'Bündnis.C...Christen.für.Deutschland': 407,
#           'Bündnis.Grundeinkommen': 0,
#           'Bürgerrechtsbewegung.Solidarität': 198,
#           'Christlich.Demokratische.Union.Deutschlands': 2349486,
#           'Christlich.Soziale.Union.in.Bayern.e.V.': 0,
#           'DEMOKRATIE.IN.BEWEGUNG': 0,
#           'DIE.EINHEIT': 0,
#           'DIE.LINKE': 324915,
#           'DIE.RECHTE': 1166,
#           'Deutsche.Kommunistische.Partei': 0,
#           'Deutsche.Mitte': 0,
#           'Die.Grauen...Für.alle.Generationen': 0,
#           'Die.Urbane..Eine.HipHop.Partei': 0,
#           'Die.Violetten': 0,
#           'FREIE.WÄHLER': 33702,
# ...

# %% [markdown]
# For each state and each party, compute the area where the party has taken the most and the least total votes

# %%
for state in states:
    print(state, v[state].most_common(1))
# Out:
# Brandenburg [('Christlich.Demokratische.Union.Deutschlands', 432172)]
# Saarland [('Christlich.Demokratische.Union.Deutschlands', 211817)]
# Hamburg [('Sozialdemokratische.Partei.Deutschlands', 311439)]
# Nordrhein-Westfalen [('Christlich.Demokratische.Union.Deutschlands', 3756833)]
# Schleswig-Holstein [('Christlich.Demokratische.Union.Deutschlands', 681381)]
# Hessen [('Christlich.Demokratische.Union.Deutschlands', 1185486)]
# Bremen [('Sozialdemokratische.Partei.Deutschlands', 104718)]
# Rheinland-Pfalz [('Christlich.Demokratische.Union.Deutschlands', 932351)]
# Niedersachsen [('Christlich.Demokratische.Union.Deutschlands', 1776995)]
# Bayern [('Christlich.Soziale.Union.in.Bayern.e.V.', 3255604)]
# Baden-Württemberg [('Christlich.Demokratische.Union.Deutschlands', 2349486)]
# Mecklenburg-Vorpommern [('Christlich.Demokratische.Union.Deutschlands', 316720)]
# Sachsen [('Christlich.Demokratische.Union.Deutschlands', 756133)]
# ...

# %% [markdown]
# For each state and each party, compute the area where the party has taken the most and the least votes, as a percentage of the overall registered voters.
