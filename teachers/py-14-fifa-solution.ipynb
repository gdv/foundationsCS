# %%
import pandas as pd

# %% [markdown]
# For some of the datasets we need to use the `low_memory` option.

# %%
complete_data = pd.read_csv('https://github.com/gdv/foundationsCS/raw/master/students/ex-data/fifa18/CompleteDataset.csv', low_memory=False)
complete_data.head()
# Out:
#    Unnamed: 0               Name  Age  \
# 0           0  Cristiano Ronaldo   32
# 1           1           L. Messi   30
# 2           2             Neymar   25
# 3           3          L. Suárez   30
# 4           4           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# ...

# %%
attribute_data = pd.read_csv('https://github.com/gdv/foundationsCS/raw/master/students/ex-data/fifa18/PlayerAttributeData.csv', low_memory=False)
attribute_data.head()
# Out:
#    Unnamed: 0 Acceleration Aggression Agility Balance Ball control Composure  \
# 0           0           89         63      89      63           93        95
# 1           1           92         48      90      95           95        96
# 2           2           94         56      96      82           95        92
# 3           3           88         78      86      60           91        83
# 4           4           58         29      52      35           48        70
#
#   Crossing Curve Dribbling  ... Reactions Short passing Shot power  \
# 0       85    81        91  ...        96            83         94
# 1       77    89        97  ...        95            88         85
# 2       75    81        96  ...        88            81         80
# 3       77    86        86  ...        93            83         87
# 4       15    14        30  ...        85            55         25
#
#   Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision Volleys
# ...

# %%
personal_data = pd.read_csv('https://github.com/gdv/foundationsCS/raw/master/students/ex-data/fifa18/PlayerPersonalData.csv')
personal_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      ID               Name  Age  \
# 0             0           0   20801  Cristiano Ronaldo   32
# 1             1           1  158023           L. Messi   30
# 2             2           2  190871             Neymar   25
# 3             3           3  176580          L. Suárez   30
# 4             4           4  167495           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# ...

# %%
personal_data.tail()
# Out:
#        Unnamed: 0.1  Unnamed: 0      ID           Name  Age  \
# 17976         17976       17976  237463      A. Kelsey   17
# 17977         17977       17977   11728  B. Richardson   47
# 17978         17978       17978  231381       J. Young   17
# 17979         17979       17979  238813   J. Lundstram   18
# 17980         17980       17980  238308      L. Sackey   18
#
#                                                  Photo Nationality  \
# 17976  https://cdn.sofifa.org/48/18/players/237463.png     England
# 17977   https://cdn.sofifa.org/48/18/players/11728.png     England
# 17978  https://cdn.sofifa.org/48/18/players/231381.png    Scotland
# 17979  https://cdn.sofifa.org/48/18/players/238813.png     England
# 17980  https://cdn.sofifa.org/48/18/players/238308.png       Ghana
#
#                                        Flag  Overall  Potential  \
# 17976   https://cdn.sofifa.org/flags/14.png       46         63
# 17977   https://cdn.sofifa.org/flags/14.png       46         46
# ...

# %%
position_data = pd.read_csv('https://github.com/gdv/foundationsCS/raw/master/students/ex-data/fifa18/PlayerPlayingPositionData.csv')
position_data.head()
# Out:
#    Unnamed: 0   CAM    CB   CDM    CF    CM      ID   LAM    LB   LCB  ...  \
# 0           0  89.0  53.0  62.0  91.0  82.0   20801  89.0  61.0  53.0  ...
# 1           1  92.0  45.0  59.0  92.0  84.0  158023  92.0  57.0  45.0  ...
# 2           2  88.0  46.0  59.0  88.0  79.0  190871  88.0  59.0  46.0  ...
# 3           3  87.0  58.0  65.0  88.0  80.0  176580  87.0  64.0  58.0  ...
# 4           4   NaN   NaN   NaN   NaN   NaN  167495   NaN   NaN   NaN  ...
#
#      RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  61.0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  57.0  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  59.0  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  64.0  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Replace Value and Wage with actual numbers

# %%
import re
human_to_int_re = re.compile('.(?P<amount>\d+\.{0,1}\d*)(?P<unit>\w{0,1})')

def unit_to_mult(unit):
    if unit == 'G':
        return 1000000000
    if unit == 'M':
        return 1000000
    if unit == 'K':
        return 1000
    return 1

def to_numeric(elem):
    m = human_to_int_re.search(elem)
    unit = m.group('unit')
    mult = unit_to_mult(unit)
    amount = float(m.group('amount'))
    return int(amount * mult)

# %%
personal_data['IntValue'] = personal_data['Value'].apply(to_numeric)
personal_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      ID               Name  Age  \
# 0             0           0   20801  Cristiano Ronaldo   32
# 1             1           1  158023           L. Messi   30
# 2             2           2  190871             Neymar   25
# 3             3           3  176580          L. Suárez   30
# 4             4           4  167495           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# ...

# %%
personal_data['IntWage'] = personal_data['Wage'].apply(to_numeric)
personal_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      ID               Name  Age  \
# 0             0           0   20801  Cristiano Ronaldo   32
# 1             1           1  158023           L. Messi   30
# 2             2           2  190871             Neymar   25
# 3             3           3  176580          L. Suárez   30
# 4             4           4  167495           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# ...

# %% [markdown]
# ## Check if there are any missing values

# %%
personal_data.isnull().any()
# Out:
# Unnamed: 0.1    False
# Unnamed: 0      False
# ID              False
# Name            False
# Age             False
# Photo           False
# Nationality     False
# Flag            False
# Overall         False
# Potential       False
# Club             True
# Club Logo       False
# Value           False
# Wage            False
# Special         False
# IntValue        False
# IntWage         False
# dtype: bool

# %%
attribute_data.isnull().any()
# Out:
# Unnamed: 0            False
# Acceleration          False
# Aggression            False
# Agility               False
# Balance               False
# Ball control          False
# Composure             False
# Crossing              False
# Curve                 False
# Dribbling             False
# Finishing             False
# Free kick accuracy    False
# GK diving             False
# GK handling           False
# GK kicking            False
# GK positioning        False
# GK reflexes           False
# Heading accuracy      False
# ID                    False
# Interceptions         False
# Jumping               False
# Long passing          False
# Long shots            False
# Marking               False
# Penalties             False
# Positioning           False
# Reactions             False
# Short passing         False
# Shot power            False
# Sliding tackle        False
# Sprint speed          False
# Stamina               False
# Standing tackle       False
# ...

# %%
complete_data.isnull().any()
# Out:
# Unnamed: 0     False
# Name           False
# Age            False
# Photo          False
# Nationality    False
#                ...
# RM              True
# RS              True
# RW              True
# RWB             True
# ST              True
# Length: 75, dtype: bool

# %%
position_data.isnull().any()
# Out:
# Unnamed: 0             False
# CAM                     True
# CB                      True
# CDM                     True
# CF                      True
# CM                      True
# ID                     False
# LAM                     True
# LB                      True
# LCB                     True
# LCM                     True
# LDM                     True
# LF                      True
# LM                      True
# LS                      True
# LW                      True
# LWB                     True
# Preferred Positions    False
# RAM                     True
# RB                      True
# RCB                     True
# RCM                     True
# RDM                     True
# RF                      True
# RM                      True
# RS                      True
# RW                      True
# RWB                     True
# ST                      True
# dtype: bool

# %% [markdown]
# ## Which teams have the most players?

# %%
personal_data.groupby('Club')['Club'].count().idxmax()
# Out:
# 'Villarreal CF'

# %% [markdown]
# ## Which team pays the largest total wages?

# %%
personal_data.groupby('Club')['IntWage'].sum().idxmax()
# Out:
# 'FC Barcelona'

# %%
personal_data.groupby('Club')['IntWage'].sum().sort_values(ascending=False).head()
# Out:
# Club
# FC Barcelona         4792000
# Real Madrid CF       4751000
# Manchester United    3653000
# Chelsea              3537000
# FC Bayern Munich     3273000
# Name: IntWage, dtype: int64

# %% [markdown]
# ## Which team pays the largest average wage?

# %%
personal_data.groupby('Club')['IntWage'].mean().sort_values(ascending=False).head()
# Out:
# Club
# FC Barcelona         191680.000000
# Real Madrid CF       182730.769231
# FC Bayern Munich     125884.615385
# Juventus             121730.769231
# Manchester United    107441.176471
# Name: IntWage, dtype: float64

# %% [markdown]
# ## How many players have exactly one preferred positions?

# %%
position_data['PP List'] = position_data['Preferred Positions'].apply(str.split)
print(len([x for x in position_data['PP List'] if len(x) == 1]))
# Out:
# 9738

# %%
position_data[position_data['PP List'].apply(len) == 1]
# Out:
#        Unnamed: 0   CAM    CB   CDM    CF    CM      ID   LAM    LB   LCB  \
# 1               1  92.0  45.0  59.0  92.0  84.0  158023  92.0  57.0  45.0
# 2               2  88.0  46.0  59.0  88.0  79.0  190871  88.0  59.0  46.0
# 3               3  87.0  58.0  65.0  88.0  80.0  176580  87.0  64.0  58.0
# 4               4   NaN   NaN   NaN   NaN   NaN  167495   NaN   NaN   NaN
# 5               5  84.0  57.0  62.0  87.0  78.0  188545  84.0  58.0  57.0
# ...           ...   ...   ...   ...   ...   ...     ...   ...   ...   ...
# 17975       17975  44.0  38.0  42.0  42.0  45.0  235352  44.0  37.0  38.0
# 17976       17976   NaN   NaN   NaN   NaN   NaN  237463   NaN   NaN   NaN
# 17977       17977   NaN   NaN   NaN   NaN   NaN   11728   NaN   NaN   NaN
# 17978       17978  44.0  28.0  29.0  45.0  38.0  231381  44.0  31.0  28.0
# 17979       17979  45.0  46.0  47.0  43.0  45.0  238813  45.0  47.0  46.0
#
#        ...   RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST  PP List
# ...

# %% [markdown]
# ## How many players have at least three preferred positions?

# %%
len(position_data[position_data['PP List'].apply(len) >= 3])
# Out:
# 2345
