# %% [markdown]
# # Pandas Groupby

# %% [markdown]
# We first need to read the files `2017_german_election_overall.csv` and `2017_german_election_party.csv` from the german-election-2017 dataset.

# %%
import pandas as pd

# %%
german_party = pd.read_csv('ex-data/german-election-2017/2017_german_election_party.csv')
german_overall = pd.read_csv('ex-data/german-election-2017/2017_german_election_overall.csv')

# %%
german_party.head()
# Out:
#    Unnamed: 0  area_id                          area_name               state  \
# 0           1        1              Flensburg – Schleswig  Schleswig-Holstein
# 1           2        2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2           3        3       Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3           4        4              Rendsburg-Eckernförde  Schleswig-Holstein
# 4           5        5                               Kiel  Schleswig-Holstein
#
#                                          party  votes_first_vote  \
# 0  Christlich.Demokratische.Union.Deutschlands             68102
# 1  Christlich.Demokratische.Union.Deutschlands             62260
# 2  Christlich.Demokratische.Union.Deutschlands             54812
# 3  Christlich.Demokratische.Union.Deutschlands             66625
# 4  Christlich.Demokratische.Union.Deutschlands             45691
#
#    votes_second_vote
# 0              58307
# 1              52933
# 2              47367
# 3              56584
# 4              40011

# %%
german_overall.head()
# Out:
#    Unnamed: 0  area_id                         area_names               state  \
# 0           1        1              Flensburg – Schleswig  Schleswig-Holstein
# 1           2        2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2           3        3       Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3           4        4              Rendsburg-Eckernförde  Schleswig-Holstein
# 4           5        5                               Kiel  Schleswig-Holstein
#
#    registered.voters  total_votes  invalid_first_votes  invalid_second_votes  \
# 0             225659       171905                 1647                  1509
# 1             186384       139200                 1299                  1125
# 2             175950       132016                 1133                  1141
# 3             199632       157387                 1285                  1119
# 4             204650       151463                 1657                  1290
#
#    valid_first_votes  valid_second_votes
# 0             170258              170396
# 1             137901              138075
# 2             130883              130875
# 3             156102              156268
# 4             149806              150173

# %% [markdown]
# ## For each state, compute the total number of registered voters

# %% [markdown]
# Hint: avoid using dictionaries and loops, leveraging on the functionalities provided by Pandas.

# %%
registered_voters = german_overall.groupby('state')['registered.voters'].sum()
registered_voters
# Out:
# state
# Baden-Württemberg          7732570
# Bayern                     9519914
# Berlin                     2503053
# Brandenburg                2051507
# Bremen                      474097
# Hamburg                    1296624
# Hessen                     4409241
# Mecklenburg-Vorpommern     1323999
# Niedersachsen              6124125
# Nordrhein-Westfalen       13174480
# Rheinland-Pfalz            3081062
# Saarland                    777263
# Sachsen                    3328669
# Sachsen-Anhalt             1854982
# Schleswig-Holstein         2258129
# Thüringen                  1765814
# Name: registered.voters, dtype: int64

# %%
type(registered_voters)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## How many registered voters are there in Bayern or Saarland (compute the voters in each state and the sum of the two numbers)

# %% [markdown]
# Using the previous Series, this exercise becomes trivial.

# %%
bayern_voters = registered_voters['Bayern']
saarland_voters = registered_voters['Saarland']
print(bayern_voters + saarland_voters)
# Out:
# 10297177

# %% [markdown]
# ## For each state, compute the number of votes (first vote) for each party

# %%
state_party_votes = german_party.groupby(['state', 'party']).sum()['votes_first_vote']
state_party_votes
# Out:
# state              party
# Baden-Württemberg  Ab.jetzt...Demokratie.durch.Volksabstimmung                        0
#                    Allianz.Deutscher.Demokraten                                       0
#                    Allianz.für.Menschenrechte.Tier..und.Naturschutz                   0
#                    Alternative.für.Deutschland                                   689893
#                    Bayernpartei                                                       0
#                                                                                   ...
# Thüringen          UNABHÄNGIGE.für.bürgernahe.Demokratie                              0
#                    V.Partei³...Partei.für.Veränderung..Vegetarier.und.Veganer      1204
#                    bergpartei..die.überpartei                                         0
#                    Ökologisch.Demokratische.Partei                                 5291
#                    Übrige                                                          6978
# Name: votes_first_vote, Length: 688, dtype: int64

# %% [markdown]
# ## For each state and each party, compute the area where the party has taken the most total votes (first votes)

# %% [markdown]
# Hint: using `max()` after a `groupby` returns the maximum **value** in the group, not the row that includes such value.
# Therefore, we need to use `idxmax()`.

# %%
german_party.loc[german_party.groupby(['state', 'party'])['votes_first_vote'].idxmax()]
# Out:
#        Unnamed: 0  area_id                                 area_name  \
# 4443         4444      258                               Stuttgart I
# 6237         6238      258                               Stuttgart I
# 6536         6537      258                               Stuttgart I
# 2060         2061      267                                 Heilbronn
# 4144         4145      258                               Stuttgart I
# ...           ...      ...                                       ...
# 12447       12448      189  Eichsfeld – Nordhausen – Kyffhäuserkreis
# 10060       10061      194           Gera – Greiz – Altenburger Land
# 6766         6767      189  Eichsfeld – Nordhausen – Kyffhäuserkreis
# 3477         3478      189  Eichsfeld – Nordhausen – Kyffhäuserkreis
# 12748       12749      191         Jena – Sömmerda – Weimarer Land I
#
#                    state                                              party  \
# 4443   Baden-Württemberg        Ab.jetzt...Demokratie.durch.Volksabstimmung
# 6237   Baden-Württemberg                       Allianz.Deutscher.Demokraten
# 6536   Baden-Württemberg   Allianz.für.Menschenrechte.Tier..und.Naturschutz
# 2060   Baden-Württemberg                        Alternative.für.Deutschland
# 4144   Baden-Württemberg                                       Bayernpartei
# ...                  ...                                                ...
# 12447          Thüringen              UNABHÄNGIGE.für.bürgernahe.Demokratie
# 10060          Thüringen  V.Partei³...Partei.für.Veränderung..Vegetarier...
# 6766           Thüringen                         bergpartei..die.überpartei
# 3477           Thüringen                    Ökologisch.Demokratische.Partei
# 12748          Thüringen                                             Übrige
#
#        votes_first_vote  votes_second_vote
# 4443                  0                  0
# 6237                  0                  0
# 6536                  0                203
# 2060              28574              30088
# 4144                  0                  0
# ...                 ...                ...
# 12447                 0                  0
# 10060              1204                726
# 6766                  0                  0
# 3477               1929               1164
# 12748              2318                  0
#
# [688 rows x 7 columns]

# %% [markdown]
# Let's manually test whether the maximum amount of votes that `Christlich.Demokratische.Union.Deutschlands` got in Baden-Württemberg was 7750.

# %%
german_party[(german_party['state'] == 'Baden-Württemberg') & \
             (german_party['party'] == 'Christlich.Demokratische.Union.Deutschlands')]
# Out:
#      Unnamed: 0  area_id                    area_name              state  \
# 257         258      258                  Stuttgart I  Baden-Württemberg
# 258         259      259                 Stuttgart II  Baden-Württemberg
# 259         260      260                    Böblingen  Baden-Württemberg
# 260         261      261                    Esslingen  Baden-Württemberg
# 261         262      262                    Nürtingen  Baden-Württemberg
# 262         263      263                    Göppingen  Baden-Württemberg
# 263         264      264                   Waiblingen  Baden-Württemberg
# 264         265      265                  Ludwigsburg  Baden-Württemberg
# 265         266      266                 Neckar-Zaber  Baden-Württemberg
# 266         267      267                    Heilbronn  Baden-Württemberg
# 267         268      268  Schwäbisch Hall – Hohenlohe  Baden-Württemberg
# 268         269      269  Backnang – Schwäbisch Gmünd  Baden-Württemberg
# 269         270      270           Aalen – Heidenheim  Baden-Württemberg
# 270         271      271              Karlsruhe-Stadt  Baden-Württemberg
# 271         272      272               Karlsruhe-Land  Baden-Württemberg
# 272         273      273                      Rastatt  Baden-Württemberg
# 273         274      274                   Heidelberg  Baden-Württemberg
# 274         275      275                     Mannheim  Baden-Württemberg
# 275         276      276            Odenwald – Tauber  Baden-Württemberg
# 276         277      277                 Rhein-Neckar  Baden-Württemberg
# 277         278      278      Bruchsal – Schwetzingen  Baden-Württemberg
# 278         279      279                    Pforzheim  Baden-Württemberg
# 279         280      280                         Calw  Baden-Württemberg
# 280         281      281                     Freiburg  Baden-Württemberg
# 281         282      282           Lörrach – Müllheim  Baden-Württemberg
# 282         283      283           Emmendingen – Lahr  Baden-Württemberg
# 283         284      284                    Offenburg  Baden-Württemberg
# 284         285      285        Rottweil – Tuttlingen  Baden-Württemberg
# 285         286      286             Schwarzwald-Baar  Baden-Württemberg
# 286         287      287                     Konstanz  Baden-Württemberg
# 287         288      288                     Waldshut  Baden-Württemberg
# 288         289      289                   Reutlingen  Baden-Württemberg
# 289         290      290                     Tübingen  Baden-Württemberg
# 290         291      291                          Ulm  Baden-Württemberg
# 291         292      292                     Biberach  Baden-Württemberg
# 292         293      293                     Bodensee  Baden-Württemberg
# 293         294      294                   Ravensburg  Baden-Württemberg
# 294         295      295     Zollernalb – Sigmaringen  Baden-Württemberg
#
#                                            party  votes_first_vote  \
# 257  Christlich.Demokratische.Union.Deutschlands             51116
# 258  Christlich.Demokratische.Union.Deutschlands             46066
# 259  Christlich.Demokratische.Union.Deutschlands             75318
# 260  Christlich.Demokratische.Union.Deutschlands             53661
# 261  Christlich.Demokratische.Union.Deutschlands             65566
# 262  Christlich.Demokratische.Union.Deutschlands             50891
# 263  Christlich.Demokratische.Union.Deutschlands             64958
# 264  Christlich.Demokratische.Union.Deutschlands             66430
# 265  Christlich.Demokratische.Union.Deutschlands             73445
# 266  Christlich.Demokratische.Union.Deutschlands             64588
# 267  Christlich.Demokratische.Union.Deutschlands             68589
# 268  Christlich.Demokratische.Union.Deutschlands             55592
# 269  Christlich.Demokratische.Union.Deutschlands             77750
# 270  Christlich.Demokratische.Union.Deutschlands             45814
# 271  Christlich.Demokratische.Union.Deutschlands             67491
# 272  Christlich.Demokratische.Union.Deutschlands             68253
# 273  Christlich.Demokratische.Union.Deutschlands             58020
# 274  Christlich.Demokratische.Union.Deutschlands             41809
# 275  Christlich.Demokratische.Union.Deutschlands             75529
# 276  Christlich.Demokratische.Union.Deutschlands             57790
# 277  Christlich.Demokratische.Union.Deutschlands             63167
# 278  Christlich.Demokratische.Union.Deutschlands             60474
# 279  Christlich.Demokratische.Union.Deutschlands             65675
# 280  Christlich.Demokratische.Union.Deutschlands             50250
# 281  Christlich.Demokratische.Union.Deutschlands             69143
# 282  Christlich.Demokratische.Union.Deutschlands             62478
# 283  Christlich.Demokratische.Union.Deutschlands             73925
# 284  Christlich.Demokratische.Union.Deutschlands             64551
# 285  Christlich.Demokratische.Union.Deutschlands             58149
# 286  Christlich.Demokratische.Union.Deutschlands             70255
# 287  Christlich.Demokratische.Union.Deutschlands             56525
# 288  Christlich.Demokratische.Union.Deutschlands             63493
# 289  Christlich.Demokratische.Union.Deutschlands             56448
# 290  Christlich.Demokratische.Union.Deutschlands             74844
# 291  Christlich.Demokratische.Union.Deutschlands             57823
# 292  Christlich.Demokratische.Union.Deutschlands             56165
# 293  Christlich.Demokratische.Union.Deutschlands             55752
# 294  Christlich.Demokratische.Union.Deutschlands             61693
#
#      votes_second_vote
# 257              46243
# 258              40071
# 259              69009
# 260              44747
# 261              56106
# 262              45285
# 263              58371
# 264              57999
# 265              60708
# 266              58754
# 267              58085
# 268              47586
# 269              64216
# 270              44764
# 271              59234
# 272              58793
# 273              53139
# 274              38743
# 275              64205
# 276              51796
# 277              53147
# 278              54360
# 279              56330
# 280              50422
# 281              60508
# 282              59782
# 283              57030
# 284              57094
# 285              46812
# 286              52221
# 287              53065
# 288              53877
# 289              48828
# 290              64983
# 291              56162
# 292              50422
# 293              56265
# 294              52282

# %% [markdown]
# ## For each party, compute the area where the party has taken the most and the least votes (first vote), as a percentage of the overall registered voters in the state.

# %% [markdown]
# To compute the required field we can use the `registered_voters` Series we computed before, together with `apply`.

# %%
german_party['percentage'] = german_party.apply(lambda row:\
                                                row['votes_first_vote'] / registered_voters[row['state']] * 100,
                                                axis=1)
german_party.head()

# %% [markdown]
# Now we can use `idxmin` and `idxmax` to solve the problem

# %%
least_perc_index = german_party.groupby('party')['percentage'].idxmin()
german_party.loc[least_perc_index][['party', 'state', 'area_name', 'percentage']]
# Out:
#                                                    party               state  \
# 4186         Ab.jetzt...Demokratie.durch.Volksabstimmung  Schleswig-Holstein
# 5980                        Allianz.Deutscher.Demokraten  Schleswig-Holstein
# 6279    Allianz.für.Menschenrechte.Tier..und.Naturschutz  Schleswig-Holstein
# 1817                         Alternative.für.Deutschland       Niedersachsen
# 3887                                        Bayernpartei  Schleswig-Holstein
# 1098                               BÜNDNIS.90.DIE.GRÜNEN     Rheinland-Pfalz
# 10166               Bündnis.C...Christen.für.Deutschland  Schleswig-Holstein
# 6877                              Bündnis.Grundeinkommen  Schleswig-Holstein
# 5083                    Bürgerrechtsbewegung.Solidarität  Schleswig-Holstein
# 211          Christlich.Demokratische.Union.Deutschlands              Bayern
# 1196             Christlich.Soziale.Union.in.Bayern.e.V.  Schleswig-Holstein
# 7176                              DEMOKRATIE.IN.BEWEGUNG  Schleswig-Holstein
# 10465                                        DIE.EINHEIT  Schleswig-Holstein
# 608                                            DIE.LINKE  Schleswig-Holstein
# 5681                                          DIE.RECHTE  Schleswig-Holstein
# 7475                      Deutsche.Kommunistische.Partei  Schleswig-Holstein
# 7774                                      Deutsche.Mitte  Schleswig-Holstein
# 8073                  Die.Grauen...Für.alle.Generationen  Schleswig-Holstein
# 8372                      Die.Urbane..Eine.HipHop.Partei  Schleswig-Holstein
# 10764                                      Die.Violetten  Schleswig-Holstein
# 2695                                        FREIE.WÄHLER  Schleswig-Holstein
# 11063                       Familien.Partei.Deutschlands  Schleswig-Holstein
# 11362                    Feministische.Partei.DIE.FRAUEN  Schleswig-Holstein
# 1721                          Freie.Demokratische.Partei              Bayern
# 8671                            Madgeburger.Gartenpartei  Schleswig-Holstein
# 4784       Marxistisch.Leninistische.Partei.Deutschlands  Schleswig-Holstein
# 8970                                    Menschliche.Welt  Schleswig-Holstein
# 11661                                       Mieterpartei  Schleswig-Holstein
# 2392           Nationaldemokratische.Partei.Deutschlands  Schleswig-Holstein
# 11960                Neue.Liberale...Die.Sozialliberalen  Schleswig-Holstein
# 2990                     PARTEI.MENSCH.UMWELT.TIERSCHUTZ  Schleswig-Holstein
# 9269                               Partei.der.Humanisten  Schleswig-Holstein
# 4485                                 Partei.der.Vernunft  Schleswig-Holstein
# 3588   Partei.für.Arbeit..Rechtsstaat..Tierschutz..El...  Schleswig-Holstein
# 9568                     Partei.für.Gesundheitsforschung  Schleswig-Holstein
# 2093                           Piratenpartei.Deutschland  Schleswig-Holstein
# 521              Sozialdemokratische.Partei.Deutschlands              Bayern
# 5382   Sozialistische.Gleichheitspartei..Vierte.Inter...  Schleswig-Holstein
# 12259              UNABHÄNGIGE.für.bürgernahe.Demokratie  Schleswig-Holstein
# 9867   V.Partei³...Partei.für.Veränderung..Vegetarier...  Schleswig-Holstein
# 6578                          bergpartei..die.überpartei  Schleswig-Holstein
# 3289                     Ökologisch.Demokratische.Partei  Schleswig-Holstein
# 12559                                             Übrige  Schleswig-Holstein
#
#                                 area_name  percentage
# 4186                Flensburg – Schleswig    0.000000
# 5980                Flensburg – Schleswig    0.000000
# 6279                Flensburg – Schleswig    0.000000
# 1817                       Aurich – Emden    0.000000
# 3887                Flensburg – Schleswig    0.000000
# 1098                              Bitburg    0.000000
# 10166               Flensburg – Schleswig    0.000000
# 6877                Flensburg – Schleswig    0.000000
# 5083                Flensburg – Schleswig    0.000000
# 211                             Altötting    0.000000
# 1196                Flensburg – Schleswig    0.000000
# 7176                Flensburg – Schleswig    0.000000
# 10465               Flensburg – Schleswig    0.000000
# 608                                Lübeck    0.000000
# 5681                Flensburg – Schleswig    0.000000
# 7475                Flensburg – Schleswig    0.000000
# 7774                Flensburg – Schleswig    0.000000
# 8073                Flensburg – Schleswig    0.000000
# 8372                Flensburg – Schleswig    0.000000
# 10764               Flensburg – Schleswig    0.000000
# 2695                                 Kiel    0.000000
# 11063               Flensburg – Schleswig    0.000000
# 11362               Flensburg – Schleswig    0.000000
# 1721                           Deggendorf    0.049444
# 8671                Flensburg – Schleswig    0.000000
# 4784                Flensburg – Schleswig    0.000000
# 8970                Flensburg – Schleswig    0.000000
# 11661               Flensburg – Schleswig    0.000000
# 2392                Flensburg – Schleswig    0.000000
# 11960               Flensburg – Schleswig    0.000000
# 2990                Flensburg – Schleswig    0.000000
# 9269                Flensburg – Schleswig    0.000000
# 4485                Flensburg – Schleswig    0.000000
# 3588                Flensburg – Schleswig    0.000000
# 9568                Flensburg – Schleswig    0.000000
# 2093                Flensburg – Schleswig    0.000000
# 521    Bad Tölz-Wolfratshausen – Miesbach    0.155369
# 5382                Flensburg – Schleswig    0.000000
# 12259               Flensburg – Schleswig    0.000000
# 9867                Flensburg – Schleswig    0.000000
# 6578                Flensburg – Schleswig    0.000000
# 3289                Flensburg – Schleswig    0.000000
# 12559   Nordfriesland – Dithmarschen Nord    0.000000

# %%
max_perc_index = german_party.groupby('party')['percentage'].idxmax()
german_party.loc[max_perc_index][['party', 'state', 'area_name', 'percentage']]
# Out:
#                                                    party  \
# 4282         Ab.jetzt...Demokratie.durch.Volksabstimmung
# 5980                        Allianz.Deutscher.Demokraten
# 6279    Allianz.für.Menschenrechte.Tier..und.Naturschutz
# 1848                         Alternative.für.Deutschland
# 4109                                        Bayernpartei
# 950                                BÜNDNIS.90.DIE.GRÜNEN
# 10210               Bündnis.C...Christen.für.Deutschland
# 6877                              Bündnis.Grundeinkommen
# 5240                    Bürgerrechtsbewegung.Solidarität
# 53           Christlich.Demokratische.Union.Deutschlands
# 1448             Christlich.Soziale.Union.in.Bayern.e.V.
# 7176                              DEMOKRATIE.IN.BEWEGUNG
# 10672                                        DIE.EINHEIT
# 651                                            DIE.LINKE
# 5947                                          DIE.RECHTE
# 7533                      Deutsche.Kommunistische.Partei
# 7774                                      Deutsche.Mitte
# 8149                  Die.Grauen...Für.alle.Generationen
# 8454                      Die.Urbane..Eine.HipHop.Partei
# 10948                                      Die.Violetten
# 2757                                        FREIE.WÄHLER
# 11071                       Familien.Partei.Deutschlands
# 11440                    Feministische.Partei.DIE.FRAUEN
# 1548                          Freie.Demokratische.Partei
# 8739                            Madgeburger.Gartenpartei
# 4837       Marxistisch.Leninistische.Partei.Deutschlands
# 9024                                    Menschliche.Welt
# 11745                                       Mieterpartei
# 2458           Nationaldemokratische.Partei.Deutschlands
# 11964                Neue.Liberale...Die.Sozialliberalen
# 3004                     PARTEI.MENSCH.UMWELT.TIERSCHUTZ
# 9269                               Partei.der.Humanisten
# 4781                                 Partei.der.Vernunft
# 3641   Partei.für.Arbeit..Rechtsstaat..Tierschutz..El...
# 9653                     Partei.für.Gesundheitsforschung
# 2388                           Piratenpartei.Deutschland
# 352              Sozialdemokratische.Partei.Deutschlands
# 5456   Sozialistische.Gleichheitspartei..Vierte.Inter...
# 12490              UNABHÄNGIGE.für.bürgernahe.Demokratie
# 10060  V.Partei³...Partei.für.Veränderung..Vegetarier...
# 6660                          bergpartei..die.überpartei
# 3477                     Ökologisch.Demokratische.Partei
# 12722                                             Übrige
#
#                         state  \
# 4282      Nordrhein-Westfalen
# 5980       Schleswig-Holstein
# 6279       Schleswig-Holstein
# 1848                   Bremen
# 4109                   Bayern
# 950                    Bremen
# 10210           Niedersachsen
# 6877       Schleswig-Holstein
# 5240                  Sachsen
# 53                     Bremen
# 1448                   Bayern
# 7176       Schleswig-Holstein
# 10672         Rheinland-Pfalz
# 651                    Bremen
# 5947        Baden-Württemberg
# 7533              Brandenburg
# 7774       Schleswig-Holstein
# 8149                   Berlin
# 8454                   Berlin
# 10948                  Hessen
# 2757           Sachsen-Anhalt
# 11071      Schleswig-Holstein
# 11440                  Berlin
# 1548                   Bremen
# 8739           Sachsen-Anhalt
# 4837                   Bremen
# 9024                   Bremen
# 11745                  Berlin
# 2458           Sachsen-Anhalt
# 11964      Schleswig-Holstein
# 3004   Mecklenburg-Vorpommern
# 9269       Schleswig-Holstein
# 4781                 Saarland
# 3641                   Bremen
# 9653                   Berlin
# 2388                 Saarland
# 352                    Bremen
# 5456                   Berlin
# 12490                  Bayern
# 10060               Thüringen
# 6660                   Berlin
# 3477                Thüringen
# 12722                 Sachsen
#
#                                                area_name  percentage
# 4282                                  Rhein-Sieg-Kreis I    0.040783
# 5980                               Flensburg – Schleswig    0.000000
# 6279                               Flensburg – Schleswig    0.000000
# 1848                             Bremen II – Bremerhaven    3.498440
# 4109                  Bad Tölz-Wolfratshausen – Miesbach    0.058425
# 950                                             Bremen I    4.671407
# 10210                                    Gifhorn – Peine    0.011806
# 6877                               Flensburg – Schleswig    0.000000
# 5240                    Sächsische Schweiz-Osterzgebirge    0.069698
# 53                                              Bremen I    9.472323
# 1448                                       Augsburg-Land    0.990051
# 7176                               Flensburg – Schleswig    0.000000
# 10672                                  Neustadt – Speyer    0.008536
# 651                                             Bremen I    4.772652
# 5947                                           Heilbronn    0.003207
# 7533                       Märkisch-Oderland – Barnim II    0.056008
# 7774                               Flensburg – Schleswig    0.000000
# 8149                                Berlin-Reinickendorf    0.066159
# 8454   Berlin-Friedrichshain-Kreuzberg – Prenzlauer B...    0.030643
# 10948                                          Offenbach    0.011839
# 2757                             Börde – Jerichower Land    0.421136
# 11071                        Ostholstein – Stormarn-Nord    0.022364
# 11440                         Berlin-Steglitz-Zehlendorf    0.017219
# 1548                                            Bremen I    4.302495
# 8739                                           Magdeburg    0.138438
# 4837                                            Bremen I    0.072348
# 9024                             Bremen II – Bremerhaven    0.155453
# 11745                         Berlin-Marzahn-Hellersdorf    0.028605
# 2458                             Börde – Jerichower Land    0.518118
# 11964                                               Kiel    0.015012
# 3004          Vorpommern-Rügen – Vorpommern-Greifswald I    0.163142
# 9269                               Flensburg – Schleswig    0.000000
# 4781                                           Saarlouis    0.031135
# 3641                                            Bremen I    1.002116
# 9653                                  Berlin-Lichtenberg    0.060886
# 2388                                         Saarbrücken    0.178189
# 352                                             Bremen I   11.617665
# 5456                                        Berlin-Mitte    0.011066
# 12490                                             Amberg    0.011229
# 10060                    Gera – Greiz – Altenburger Land    0.068184
# 6660   Berlin-Friedrichshain-Kreuzberg – Prenzlauer B...    0.026847
# 3477            Eichsfeld – Nordhausen – Kyffhäuserkreis    0.109241
# 12722                                            Zwickau    0.427799

# %% [markdown]
# ## For each area, compute the difference between the valid first votes and the valid second votes

# %%
german_party['difference'] = german_party['votes_first_vote'] - german_party['votes_second_vote']
german_party.groupby('area_name').sum()['difference']
# Out:
# area_name
# Aachen I                    -445
# Aachen II                   -443
# Aalen – Heidenheim          -627
# Ahrweiler                   -395
# Altmark                     -410
#                             ...
# Worms                       -491
# Wuppertal I                 -562
# Würzburg                    -621
# Zollernalb – Sigmaringen    -536
# Zwickau                    -5433
# Name: difference, Length: 299, dtype: int64

# %% [markdown]
# ## For each state, compute the difference between the valid first votes and the valid second votes

# %%
german_party.groupby('state').sum()['difference']
# Out:
# state
# Baden-Württemberg        -11811
# Bayern                   -21451
# Berlin                    -3340
# Brandenburg               -2427
# Bremen                    -1625
# Hamburg                   -2767
# Hessen                    -4323
# Mecklenburg-Vorpommern     -644
# Niedersachsen            -11723
# Nordrhein-Westfalen      -39164
# Rheinland-Pfalz          -10622
# Saarland                    123
# Sachsen                   -9646
# Sachsen-Anhalt            -8551
# Schleswig-Holstein        -2650
# Thüringen                 -1706
# Name: difference, dtype: int64

# %% [markdown]
# ## For each party, compute the difference between the first votes and the second votes

# %%
german_party.groupby('party').sum()['difference']
# Out:
# party
# Ab.jetzt...Demokratie.durch.Volksabstimmung                                                        -3579
# Allianz.Deutscher.Demokraten                                                                      -41178
# Allianz.für.Menschenrechte.Tier..und.Naturschutz                                                  -32218
# Alternative.für.Deutschland                                                                      -560999
# Bayernpartei                                                                                        4604
# BÜNDNIS.90.DIE.GRÜNEN                                                                            -440128
# Bündnis.C...Christen.für.Deutschland                                                                1715
# Bündnis.Grundeinkommen                                                                            -97386
# Bürgerrechtsbewegung.Solidarität                                                                    9258
# Christlich.Demokratische.Union.Deutschlands                                                      1581972
# Christlich.Soziale.Union.in.Bayern.e.V.                                                           385860
# DEMOKRATIE.IN.BEWEGUNG                                                                            -60826
# DIE.EINHEIT                                                                                          373
# DIE.LINKE                                                                                        -330727
# DIE.RECHTE                                                                                          -904
# Deutsche.Kommunistische.Partei                                                                     -4199
# Deutsche.Mitte                                                                                    -63133
# Die.Grauen...Für.alle.Generationen                                                                 -5563
# Die.Urbane..Eine.HipHop.Partei                                                                     -2251
# Die.Violetten                                                                                       2187
# FREIE.WÄHLER                                                                                      126064
# Familien.Partei.Deutschlands                                                                         505
# Feministische.Partei.DIE.FRAUEN                                                                      431
# Freie.Demokratische.Partei                                                                      -1748433
# Madgeburger.Gartenpartei                                                                           -3038
# Marxistisch.Leninistische.Partei.Deutschlands                                                       5907
# Menschliche.Welt                                                                                   -9509
# Mieterpartei                                                                                        1322
# Nationaldemokratische.Partei.Deutschlands                                                        -131476
# Neue.Liberale...Die.Sozialliberalen                                                                  877
# PARTEI.MENSCH.UMWELT.TIERSCHUTZ                                                                  -350391
# Partei.der.Humanisten                                                                              -5989
# Partei.der.Vernunft                                                                                 -290
# Partei.für.Arbeit..Rechtsstaat..Tierschutz..Elitenförderung.und.basisdemokratische.Initiative    -207507
# Partei.für.Gesundheitsforschung                                                                   -22073
# Piratenpartei.Deutschland                                                                         -80694
# Sozialdemokratische.Partei.Deutschlands                                                          1888246
# Sozialistische.Gleichheitspartei..Vierte.Internationale                                             -443
# UNABHÄNGIGE.für.bürgernahe.Demokratie                                                               2455
# V.Partei³...Partei.für.Veränderung..Vegetarier.und.Veganer                                        -62926
# bergpartei..die.überpartei                                                                          -260
# Ökologisch.Demokratische.Partei                                                                    21360
# Übrige                                                                                            100657
# Name: difference, dtype: int64

# %% [markdown]
# ## For each state and each party, compute the difference between the first votes and the second votes

# %%
german_party.groupby(['state', 'party']).sum()['difference']
# Out:
# state              party
# Baden-Württemberg  Ab.jetzt...Demokratie.durch.Volksabstimmung                       0
#                    Allianz.Deutscher.Demokraten                                      0
#                    Allianz.für.Menschenrechte.Tier..und.Naturschutz             -13498
#                    Alternative.für.Deutschland                                  -40372
#                    Bayernpartei                                                      0
#                                                                                  ...
# Thüringen          UNABHÄNGIGE.für.bürgernahe.Demokratie                             0
#                    V.Partei³...Partei.für.Veränderung..Vegetarier.und.Veganer    -2264
#                    bergpartei..die.überpartei                                        0
#                    Ökologisch.Demokratische.Partei                               -1111
#                    Übrige                                                         6978
# Name: difference, Length: 688, dtype: int64
