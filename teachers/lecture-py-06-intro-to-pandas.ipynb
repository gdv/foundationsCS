# %% [markdown]
# # Pandas
#
# First we have to import the library

# %%
import pandas as pd

# %% [markdown]
# Read the [ex-data/Northwind/Orders.csv](https://github.com/gdv/foundationsCS/raw/main/students/ex-data/Northwind/Orders.csv) file. Notice that the contents of the file are now in a `DataFrame`

# %%
orders = pd.read_csv("https://github.com/gdv/foundationsCS/raw/main/students/ex-data/Northwind/Orders.csv")

# %%
orders
# Out:
#           Id CustomerId  EmployeeId            OrderDate         RequiredDate  \
# 0      10248      VINET           5           2012-07-04           2012-08-01
# 1      10249      TOMSP           6           2012-07-05           2012-08-16
# 2      10250      HANAR           4           2012-07-08           2012-08-05
# 3      10251      VICTE           3           2012-07-08           2012-08-05
# 4      10252      SUPRD           4           2012-07-09           2012-08-06
# ...      ...        ...         ...                  ...                  ...
# 16813  27061      FOLKO           5  2013-06-29 21:05:55  2013-08-02 04:10:53
# 16814  27062      FRANK           2  2014-01-19 12:27:11  2014-01-24 15:15:31
# 16815  27063      ALFKI           5  2014-10-15 09:51:09  2014-11-11 14:31:37
# 16816  27064      TRADH           8  2013-02-07 02:06:05  2013-03-14 09:43:16
# 16817  27065      ANATR           1  2013-08-31 02:59:28  2013-09-15 23:11:49
#
# ...

# %% [markdown]
# ## Most common `read_csv` options
#
# *  `sep` or `delimiter`: the string that separates the fields.
# *  `delim_whitespace`: a boolean that states if any whitespace is the delimiter
# *  `skiprows`: lines to skip. Usually at the beginning of the file, if it contains a comment
# *  `nrows`: number of rows to read. Useful for debugging on huge files
# *  `low_memory`: boolean (default `True`). Sometimes messes up parsing
# *  `na_values`, `keep_default_na`, `na_filter`: change the default behavior for parsing missing data
# *  `parse_dates`: dates are a mess to parse. State which columns contain dates
# *  `infer_datetime_format`, `dayfirst`: may speed up parsing dates
# *  `thousands`, `decimal`: hints for parsing non US-based numbers
# *  `encoding`: sometimes you have to set it to `utf-8`

# %% [markdown]
# ## Series vs DataFrame
#
# A `Series` has a single column. A `DataFrame` at least two columns and an index.

# %% [markdown]
# Extract the column `CustomerId` from `Orders`

# %%
orders['CustomerId']
# Out:
# 0        VINET
# 1        TOMSP
# 2        HANAR
# 3        VICTE
# 4        SUPRD
#          ...
# 16813    FOLKO
# 16814    FRANK
# 16815    ALFKI
# 16816    TRADH
# 16817    ANATR
# Name: CustomerId, Length: 16818, dtype: object

# %% [markdown]
# What does it happen if I use the wrong column name?

# %%
orders['custormerid']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/standard/lib/python3.10/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~/mambaforge/envs/standard/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/mambaforge/envs/standard/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'custormerid'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
type(orders['CustomerId'])
# Out:
# pandas.core.series.Series

# %%
type(orders)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Show the first rows of `Orders`

# %%
orders.head()
# Out:
#       Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# 0  10248      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 1  10249      TOMSP           6  2012-07-05   2012-08-16  2012-07-10        1
# 2  10250      HANAR           4  2012-07-08   2012-08-05  2012-07-12        2
# 3  10251      VICTE           3  2012-07-08   2012-08-05  2012-07-15        1
# 4  10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11        2
#
#    Freight                   ShipName           ShipAddress        ShipCity  \
# 0    16.75  Vins et alcools Chevalier    59 rue de l'Abbaye           Reims
# 1    22.25         Toms Spezialitäten         Luisenstr. 48         Münster
# 2    25.00              Hanari Carnes       Rua do Paço, 67  Rio de Janeiro
# 3    20.25       Victuailles en stock    2, rue du Commerce            Lyon
# 4    36.25           Suprêmes délices  Boulevard Tirou, 255       Charleroi
#
# ...

# %% [markdown]
# Show the size of `Orders`

# %%
orders.shape
# Out:
# (16818, 14)

# %% [markdown]
# Show the column names of `Orders`

# %%
orders.columns
# Out:
# Index(['Id', 'CustomerId', 'EmployeeId', 'OrderDate', 'RequiredDate',
#        'ShippedDate', 'ShipVia', 'Freight', 'ShipName', 'ShipAddress',
#        'ShipCity', 'ShipRegion', 'ShipPostalCode', 'ShipCountry'],
#       dtype='object')

# %% [markdown]
# Change the column name `ShipVia` to `Via`

# %%
orders.rename(columns = {'ShipVia': 'Via'})
orders.head()
# Out:
#       Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# 0  10248      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 1  10249      TOMSP           6  2012-07-05   2012-08-16  2012-07-10        1
# 2  10250      HANAR           4  2012-07-08   2012-08-05  2012-07-12        2
# 3  10251      VICTE           3  2012-07-08   2012-08-05  2012-07-15        1
# 4  10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11        2
#
#    Freight                   ShipName           ShipAddress        ShipCity  \
# 0    16.75  Vins et alcools Chevalier    59 rue de l'Abbaye           Reims
# 1    22.25         Toms Spezialitäten         Luisenstr. 48         Münster
# 2    25.00              Hanari Carnes       Rua do Paço, 67  Rio de Janeiro
# 3    20.25       Victuailles en stock    2, rue du Commerce            Lyon
# 4    36.25           Suprêmes délices  Boulevard Tirou, 255       Charleroi
#
# ...

# %%
newdf = orders.rename(columns = {'ShipVia': 'Via'})
newdf.head()
# Out:
#       Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  Via  \
# 0  10248      VINET           5  2012-07-04   2012-08-01  2012-07-16    3
# 1  10249      TOMSP           6  2012-07-05   2012-08-16  2012-07-10    1
# 2  10250      HANAR           4  2012-07-08   2012-08-05  2012-07-12    2
# 3  10251      VICTE           3  2012-07-08   2012-08-05  2012-07-15    1
# 4  10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11    2
#
#    Freight                   ShipName           ShipAddress        ShipCity  \
# 0    16.75  Vins et alcools Chevalier    59 rue de l'Abbaye           Reims
# 1    22.25         Toms Spezialitäten         Luisenstr. 48         Münster
# 2    25.00              Hanari Carnes       Rua do Paço, 67  Rio de Janeiro
# 3    20.25       Victuailles en stock    2, rue du Commerce            Lyon
# 4    36.25           Suprêmes délices  Boulevard Tirou, 255       Charleroi
#
#        ShipRegion ShipPostalCode ShipCountry
# ...

# %% [markdown]
# Build a new column `Freight_kg` obtained by multiplying `Freight` by 1000

# %%
orders['Freight_kg'] = 1000 * orders['Freight']
orders.head()
# Out:
#       Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# 0  10248      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 1  10249      TOMSP           6  2012-07-05   2012-08-16  2012-07-10        1
# 2  10250      HANAR           4  2012-07-08   2012-08-05  2012-07-12        2
# 3  10251      VICTE           3  2012-07-08   2012-08-05  2012-07-15        1
# 4  10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11        2
#
#    Freight                   ShipName           ShipAddress        ShipCity  \
# 0    16.75  Vins et alcools Chevalier    59 rue de l'Abbaye           Reims
# 1    22.25         Toms Spezialitäten         Luisenstr. 48         Münster
# 2    25.00              Hanari Carnes       Rua do Paço, 67  Rio de Janeiro
# 3    20.25       Victuailles en stock    2, rue du Commerce            Lyon
# 4    36.25           Suprêmes délices  Boulevard Tirou, 255       Charleroi
#
# ...

# %% [markdown]
# Use `Id` as the index

# %%
orders.set_index('Id')
# Out:
#       CustomerId  EmployeeId            OrderDate         RequiredDate  \
# Id
# 10248      VINET           5           2012-07-04           2012-08-01
# 10249      TOMSP           6           2012-07-05           2012-08-16
# 10250      HANAR           4           2012-07-08           2012-08-05
# 10251      VICTE           3           2012-07-08           2012-08-05
# 10252      SUPRD           4           2012-07-09           2012-08-06
# ...          ...         ...                  ...                  ...
# 27061      FOLKO           5  2013-06-29 21:05:55  2013-08-02 04:10:53
# 27062      FRANK           2  2014-01-19 12:27:11  2014-01-24 15:15:31
# 27063      ALFKI           5  2014-10-15 09:51:09  2014-11-11 14:31:37
# 27064      TRADH           8  2013-02-07 02:06:05  2013-03-14 09:43:16
# 27065      ANATR           1  2013-08-31 02:59:28  2013-09-15 23:11:49
#
#                ShippedDate  ShipVia  Freight                        ShipName  \
# Id
# ...

# %%
orders.head()
# Out:
#       Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# 0  10248      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 1  10249      TOMSP           6  2012-07-05   2012-08-16  2012-07-10        1
# 2  10250      HANAR           4  2012-07-08   2012-08-05  2012-07-12        2
# 3  10251      VICTE           3  2012-07-08   2012-08-05  2012-07-15        1
# 4  10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11        2
#
#    Freight                   ShipName           ShipAddress        ShipCity  \
# 0    16.75  Vins et alcools Chevalier    59 rue de l'Abbaye           Reims
# 1    22.25         Toms Spezialitäten         Luisenstr. 48         Münster
# 2    25.00              Hanari Carnes       Rua do Paço, 67  Rio de Janeiro
# 3    20.25       Victuailles en stock    2, rue du Commerce            Lyon
# 4    36.25           Suprêmes délices  Boulevard Tirou, 255       Charleroi
#
# ...

# %%
orders.set_index('Id', inplace = True)
orders.head()
# Out:
#       CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# Id
# 10248      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 10249      TOMSP           6  2012-07-05   2012-08-16  2012-07-10        1
# 10250      HANAR           4  2012-07-08   2012-08-05  2012-07-12        2
# 10251      VICTE           3  2012-07-08   2012-08-05  2012-07-15        1
# 10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11        2
#
#        Freight                   ShipName           ShipAddress  \
# Id
# 10248    16.75  Vins et alcools Chevalier    59 rue de l'Abbaye
# 10249    22.25         Toms Spezialitäten         Luisenstr. 48
# 10250    25.00              Hanari Carnes       Rua do Paço, 67
# 10251    20.25       Victuailles en stock    2, rue du Commerce
# 10252    36.25           Suprêmes délices  Boulevard Tirou, 255
#
#              ShipCity      ShipRegion ShipPostalCode ShipCountry  Freight_kg
# Id
# ...

# %% [markdown]
# Restore the old index

# %%
orders.reset_index(inplace = True)

# %%
orders.head()
# Out:
#       Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# 0  10248      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 1  10249      TOMSP           6  2012-07-05   2012-08-16  2012-07-10        1
# 2  10250      HANAR           4  2012-07-08   2012-08-05  2012-07-12        2
# 3  10251      VICTE           3  2012-07-08   2012-08-05  2012-07-15        1
# 4  10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11        2
#
#    Freight                   ShipName           ShipAddress        ShipCity  \
# 0    16.75  Vins et alcools Chevalier    59 rue de l'Abbaye           Reims
# 1    22.25         Toms Spezialitäten         Luisenstr. 48         Münster
# 2    25.00              Hanari Carnes       Rua do Paço, 67  Rio de Janeiro
# 3    20.25       Victuailles en stock    2, rue du Commerce            Lyon
# 4    36.25           Suprêmes délices  Boulevard Tirou, 255       Charleroi
#
# ...

# %% [markdown]
# Extract all rows where `ShipVia` is equal to 2

# %%
orders[orders['ShipVia'] == 2]
# Out:
#           Id CustomerId  EmployeeId            OrderDate         RequiredDate  \
# 2      10250      HANAR           4           2012-07-08           2012-08-05
# 4      10252      SUPRD           4           2012-07-09           2012-08-06
# 5      10253      HANAR           3           2012-07-10           2012-07-24
# 6      10254      CHOPS           5           2012-07-11           2012-08-08
# 8      10256      WELLI           3           2012-07-15           2012-08-12
# ...      ...        ...         ...                  ...                  ...
# 16805  27053      GREAL           5  2015-03-11 05:01:22  2015-04-16 11:32:55
# 16806  27054      LEHMS           7  2015-07-03 10:33:10  2015-07-28 18:20:58
# 16810  27058      SPECD           7  2013-01-26 20:46:03  2013-02-23 17:45:40
# 16811  27059      BLAUS           3  2013-10-24 03:03:17  2013-11-13 15:25:08
# 16814  27062      FRANK           2  2014-01-19 12:27:11  2014-01-24 15:15:31
#
# ...

# %% [markdown]
# What is `orders['ShipVia'] == 2`?

# %%
orders['ShipVia'] == 2
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 16813    False
# 16814     True
# 16815    False
# 16816    False
# 16817    False
# Name: ShipVia, Length: 16818, dtype: bool

# %% [markdown]
# Extract the `Id` of the rows where `ShipVia` is equal to 2

# %%
orders[orders['ShipVia'] == 2]['Id']
# Out:
# 2        10250
# 4        10252
# 5        10253
# 6        10254
# 8        10256
#          ...
# 16805    27053
# 16806    27054
# 16810    27058
# 16811    27059
# 16814    27062
# Name: Id, Length: 5592, dtype: int64

# %% [markdown]
# Extract the `Id` and `CustomerId` of the rows where `ShipVia` is equal to 2

# %%
orders[orders['ShipVia'] == 2][['Id', 'CustomerId']]
# Out:
#           Id CustomerId
# 2      10250      HANAR
# 4      10252      SUPRD
# 5      10253      HANAR
# 6      10254      CHOPS
# 8      10256      WELLI
# ...      ...        ...
# 16805  27053      GREAL
# 16806  27054      LEHMS
# 16810  27058      SPECD
# 16811  27059      BLAUS
# 16814  27062      FRANK
#
# [5592 rows x 2 columns]

# %% [markdown]
# Use `Id` as the index

# %%
orders.set_index('Id', inplace = True)

# %%
orders.head(10)
# Out:
#       CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# Id
# 10248      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 10249      TOMSP           6  2012-07-05   2012-08-16  2012-07-10        1
# 10250      HANAR           4  2012-07-08   2012-08-05  2012-07-12        2
# 10251      VICTE           3  2012-07-08   2012-08-05  2012-07-15        1
# 10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11        2
# 10253      HANAR           3  2012-07-10   2012-07-24  2012-07-16        2
# 10254      CHOPS           5  2012-07-11   2012-08-08  2012-07-23        2
# 10255      RICSU           9  2012-07-12   2012-08-09  2012-07-15        3
# 10256      WELLI           3  2012-07-15   2012-08-12  2012-07-17        2
# 10257      HILAA           4  2012-07-16   2012-08-13  2012-07-22        3
#
#        Freight                   ShipName  \
# Id
# 10248    16.75  Vins et alcools Chevalier
# 10249    22.25         Toms Spezialitäten
# ...

# %% [markdown]
# Extract the fifth and tenth row.

# %%
orders.iloc[[4, 9]]
# Out:
#       CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# Id
# 10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11        2
# 10257      HILAA           4  2012-07-16   2012-08-13  2012-07-22        3
#
#        Freight          ShipName                                 ShipAddress  \
# Id
# 10252    36.25  Suprêmes délices                        Boulevard Tirou, 255
# 10257    21.50  HILARION-Abastos  Carrera 22 con Ave. Carlos Soublette #8-35
#
#             ShipCity      ShipRegion ShipPostalCode ShipCountry  Freight_kg
# Id
# 10252      Charleroi  Western Europe         B-6000     Belgium     36250.0
# 10257  San Cristóbal   South America           5022   Venezuela     21500.0

# %% [markdown]
# Extract the rows with `Id` equal to 10252, 10257.

# %%
orders.loc[[10252, 10257]]
# Out:
#       CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# Id
# 10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11        2
# 10257      HILAA           4  2012-07-16   2012-08-13  2012-07-22        3
#
#        Freight          ShipName                                 ShipAddress  \
# Id
# 10252    36.25  Suprêmes délices                        Boulevard Tirou, 255
# 10257    21.50  HILARION-Abastos  Carrera 22 con Ave. Carlos Soublette #8-35
#
#             ShipCity      ShipRegion ShipPostalCode ShipCountry  Freight_kg
# Id
# 10252      Charleroi  Western Europe         B-6000     Belgium     36250.0
# 10257  San Cristóbal   South America           5022   Venezuela     21500.0
