# %%
import pandas as pd

# %% [markdown]
# ## Read the titles dataframe

# %%
snl = pd.read_csv('https://github.com/gdv/foundationsCS/raw/main/students/ex-data/snldb/snl_title.csv')

# %%
snl.head()
# Out:
#    sid  eid         tid                                     title  \
# 0    3   20  1978052013  "Space is the Place", "Space-Loneliness"
# 1    2   21  1977051416                                       NaN
# 2    3   18  1978042215                                       NaN
# 3    3   20  1978052014                                       NaN
# 4    3   18  1978042214                       Next Week In Review
#
#              titleType
# 0  Musical Performance
# 1           Goodnights
# 2           Goodnights
# 3           Goodnights
# 4                 Show

# %% [markdown]
# ## Remove all rows that do not have a title

# %% [markdown]
# The simplest approach is to use the **dropna**, but this function removes the rows with *any* missing value: therefore it does not work if there are more fields with missing values.
#
# We extract the index of the rows that do not have a missing title

# %%
clean_idx = snl['title'].notnull()

# %% [markdown]
# Then we use the fancy indexing

# %%
snl[clean_idx]
# Out:
#        sid  eid         tid                                     title  \
# 0        3   20  1978052013  "Space is the Place", "Space-Loneliness"
# 4        3   18  1978042214                       Next Week In Review
# 13       2   20  1977042314                    Trans Eastern Airlines
# 15       7   20  1982052214                               "Landslide"
# 17       7   20  1982052215                                 The Clams
# ...    ...  ...         ...                                       ...
# 11692   11   18   198605249              "Let's Take It To The Stage"
# 11693   11   18   198605246    National Council of Liquor and Spirits
# 11694   11   18   198605247                            Actors On Film
# 11695   11   18   198605244                          Moments Of Doubt
# 11697   11   18   198605245                        Glamorous Drinking
#
#                  titleType
# 0      Musical Performance
# 4                     Show
# 13                  Sketch
# 15     Musical Performance
# 17              Commercial
# ...                    ...
# 11692  Musical Performance
# 11693           Commercial
# 11694                 Show
# 11695               Sketch
# 11697               Sketch
#
# [9183 rows x 5 columns]

# %% [markdown]
# Another way is to explore the options of `dropna`. More precisely, the `subset` option.

# %%
snl.dropna(subset=['title'])
# Out:
#        sid  eid         tid                                     title  \
# 0        3   20  1978052013  "Space is the Place", "Space-Loneliness"
# 4        3   18  1978042214                       Next Week In Review
# 13       2   20  1977042314                    Trans Eastern Airlines
# 15       7   20  1982052214                               "Landslide"
# 17       7   20  1982052215                                 The Clams
# ...    ...  ...         ...                                       ...
# 11692   11   18   198605249              "Let's Take It To The Stage"
# 11693   11   18   198605246    National Council of Liquor and Spirits
# 11694   11   18   198605247                            Actors On Film
# 11695   11   18   198605244                          Moments Of Doubt
# 11697   11   18   198605245                        Glamorous Drinking
#
#                  titleType
# 0      Musical Performance
# 4                     Show
# 13                  Sketch
# 15     Musical Performance
# 17              Commercial
# ...                    ...
# 11692  Musical Performance
# 11693           Commercial
# 11694                 Show
# 11695               Sketch
# 11697               Sketch
#
# [9183 rows x 5 columns]

# %% [markdown]
# ## 2. Build a DataFrame with index the pair (season id, episode id).

# %%
sk34 = snl.set_index(['sid', 'eid'])

# %%
sk34.head()
# Out:
#                 tid                                     title  \
# sid eid
# 3   20   1978052013  "Space is the Place", "Space-Loneliness"
# 2   21   1977051416                                       NaN
# 3   18   1978042215                                       NaN
#     20   1978052014                                       NaN
#     18   1978042214                       Next Week In Review
#
#                    titleType
# sid eid
# 3   20   Musical Performance
# 2   21            Goodnights
# 3   18            Goodnights
#     20            Goodnights
#     18                  Show

# %% [markdown]
# Check if the index has been correctly set

# %%
sk34.index.names
# Out:
# FrozenList(['sid', 'eid'])

# %% [markdown]
# ## 3. Extract the sketches of seasons 3 and 4.

# %% [markdown]
# If we want to use slices, then we need to sort the dataframe according to the index

# %%
sk34.sort_index(inplace=True)

# %%
sk34.head()
# Out:
#                 tid            title            titleType
# sid eid
# 1   1    1975101126              NaN           Goodnights
#     1    1975101125  "In The Winter"  Musical Performance
#     1    1975101124      Triple-Trac           Commercial
#     1    1975101123  Home Securities               Sketch
#     1    1975101122     "Fancy Lady"  Musical Performance

# %% [markdown]
# We can use *loc* with either a list of values or a slice. We are going for the list.

# %%
sk34.loc[[3, 4]]
# Out:
#                 tid                            title            titleType
# sid eid
# 3   1    1977092413                              NaN           Goodnights
#     1    1977092412                  "The Pretender"  Musical Performance
#     1    1977092411                  Royal Deluxe II           Commercial
#     1    1977092410       The Franken and Davis Show                 Show
#     1     197709248              Keypunch Confession               Sketch
# ...             ...                              ...                  ...
# 4   20    197905263  Ray's Disco Roller Fishing Park           Commercial
#     20    197905262                              NaN            Monologue
#     20    197905266                    "Married Men"  Musical Performance
#     20    197905269       The Franken and Davis Show                 Show
#     20    197905261                         Mr. Bill         Cold Opening
#
# [540 rows x 3 columns]

# %% [markdown]
# Now we can impose a search condition (like the `where` part of a SQL query)

# %%
sk34[sk34['titleType'] == 'Sketch']
# Out:
#                 tid                   title titleType
# sid eid
# 1   1    1975101123         Home Securities    Sketch
#     1    1975101114       The Land of Gorch    Sketch
#     1     197510115                   Trial    Sketch
#     2    1975101812       The Land of Gorch    Sketch
#     3    1975102520                    Bees    Sketch
# ...             ...                     ...       ...
# 42  11    201701147  Susan B. Anthony House    Sketch
#     11    201701145           Theatre Donor    Sketch
#     12   2017012111              Pizza Town    Sketch
#     12    201701219              Dirty Talk    Sketch
#     12    201701214           Interrogation    Sketch
#
# [2755 rows x 3 columns]

# %%
sk34[sk34['titleType'] == 'Sketch']
# Out:
#                 tid                   title titleType
# sid eid
# 1   1    1975101123         Home Securities    Sketch
#     1    1975101114       The Land of Gorch    Sketch
#     1     197510115                   Trial    Sketch
#     2    1975101812       The Land of Gorch    Sketch
#     3    1975102520                    Bees    Sketch
# ...             ...                     ...       ...
# 42  11    201701147  Susan B. Anthony House    Sketch
#     11    201701145           Theatre Donor    Sketch
#     12   2017012111              Pizza Town    Sketch
#     12    201701219              Dirty Talk    Sketch
#     12    201701214           Interrogation    Sketch
#
# [2755 rows x 3 columns]

# %% [markdown]
# With the slice

# %%
sk34.loc[3:4]
# Out:
#                 tid                            title            titleType
# sid eid
# 3   1    1977092413                              NaN           Goodnights
#     1    1977092412                  "The Pretender"  Musical Performance
#     1    1977092411                  Royal Deluxe II           Commercial
#     1    1977092410       The Franken and Davis Show                 Show
#     1     197709248              Keypunch Confession               Sketch
# ...             ...                              ...                  ...
# 4   20    197905263  Ray's Disco Roller Fishing Park           Commercial
#     20    197905262                              NaN            Monologue
#     20    197905266                    "Married Men"  Musical Performance
#     20    197905269       The Franken and Davis Show                 Show
#     20    197905261                         Mr. Bill         Cold Opening
#
# [540 rows x 3 columns]

# %% [markdown]
# Another way is to reset the index, so that the season id becomes a column, then query the dataframe.

# %%
flat = sk34.reset_index()

# %%
flat[(flat['titleType'] == 'Sketch') & ((flat['sid'] == 3) | (flat['sid'] == 4))]
# Out:
#       sid  eid         tid                            title titleType
# 849     3    1   197709248              Keypunch Confession    Sketch
# 851     3    1   197709247      Mike McMack, Defense Lawyer    Sketch
# 852     3    1   197709249     Great Moments In Rock & Roll    Sketch
# 858     3    2  1977100817                       Phone Call    Sketch
# 861     3    2  1977100814                         Hercules    Sketch
# ...   ...  ...         ...                              ...       ...
# 1355    4   18   197905128  Boulevard Of Proud Chicano Cars    Sketch
# 1362    4   19  1979051913                      Candy Store    Sketch
# 1365    4   19   197905197                Mother & Daughter    Sketch
# 1370    4   19   197905194              Houseguest Idi Amin    Sketch
# 1378    4   20  1979052610                 The Olympia Cafe    Sketch
#
# [122 rows x 5 columns]

# %% [markdown]
# In this case, the first solution is simpler, even though it requires two separate steps.
