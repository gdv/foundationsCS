# %% [markdown]
# The Apache dataset contains the files [access.log](https://github.com/gdv/foundationsCS/raw/main/students/ex-data/apache/access.log) and [error.log](https://github.com/gdv/foundationsCS/raw/main/students/ex-data/apache/error.log) that contains the logfile of the accesses to a web server and the errors.
# The *access.log* is in [Common Log Format](https://en.wikipedia.org/wiki/Common_Log_Format).
# The entries in *error.log* usually have a corresponding entry in *access.log*

# %% [markdown]
# ## Read the file *access.log*. This file is not trivial to read correctly.

# %%
import pandas as pd
import re

# %% [markdown]
# Hint: The first row of the file *access.log* does not contain the names of the columns: we can use the `names` option.
#
# Hint: We use a custom separator, otherwise the fields `type`, `url`, and `prot` would be combined together.

# %%
access = pd.read_csv('https://github.com/gdv/foundationsCS/raw/main/students/ex-data/apache/access.log', 
                     sep='[\s\t]+',
                     names = ['origin', 'identity', 'user', 'time', 'tz', 'type', 'url', 'prot', 'status', 'size'],
                    dtype = {'size': 'Int64', 'status': 'Int64'}, na_values  = {'size': '-'})
access.head()
# Out:
# /tmp/ipykernel_264184/2732669525.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   access = pd.read_csv('https://github.com/gdv/foundationsCS/raw/main/students/ex-data/apache/access.log',
#          origin identity user                   time      tz  type  \
# 0  64.242.88.10        -    -  [07/Mar/2004:16:05:49  -0800]  "GET
# 1  64.242.88.10        -    -  [07/Mar/2004:16:06:51  -0800]  "GET
# 2  64.242.88.10        -    -  [07/Mar/2004:16:10:02  -0800]  "GET
# 3  64.242.88.10        -    -  [07/Mar/2004:16:11:58  -0800]  "GET
# 4  64.242.88.10        -    -  [07/Mar/2004:16:20:55  -0800]  "GET
#
#                                                  url       prot  status   size
# 0  /twiki/bin/edit/Main/Double_bounce_sender?topi...  HTTP/1.1"     401  12846
# 1  /twiki/bin/rdiff/TWiki/NewUserTemplate?rev1=1....  HTTP/1.1"     200   4523
# 2                       /mailman/listinfo/hsdivision  HTTP/1.1"     200   6291
# 3                   /twiki/bin/view/TWiki/WikiSyntax  HTTP/1.1"     200   7352
# 4                 /twiki/bin/view/Main/DCCAndPostFix  HTTP/1.1"     200   5253

# %%
access['time'] = access['time'].str.replace(r'^\[', '', regex = True)
access['tz'] = access['tz'].str.replace(r'\]$', '', regex = True)
access['type'] = access['type'].str.replace(r'^\"', '', regex = True)
access['prot'] = access['prot'].str.replace(r'"$', '', regex = True)
access.head()
# Out:
#          origin identity user                  time     tz type  \
# 0  64.242.88.10        -    -  07/Mar/2004:16:05:49  -0800  GET
# 1  64.242.88.10        -    -  07/Mar/2004:16:06:51  -0800  GET
# 2  64.242.88.10        -    -  07/Mar/2004:16:10:02  -0800  GET
# 3  64.242.88.10        -    -  07/Mar/2004:16:11:58  -0800  GET
# 4  64.242.88.10        -    -  07/Mar/2004:16:20:55  -0800  GET
#
#                                                  url      prot  status   size
# 0  /twiki/bin/edit/Main/Double_bounce_sender?topi...  HTTP/1.1     401  12846
# 1  /twiki/bin/rdiff/TWiki/NewUserTemplate?rev1=1....  HTTP/1.1     200   4523
# 2                       /mailman/listinfo/hsdivision  HTTP/1.1     200   6291
# 3                   /twiki/bin/view/TWiki/WikiSyntax  HTTP/1.1     200   7352
# 4                 /twiki/bin/view/Main/DCCAndPostFix  HTTP/1.1     200   5253

# %%
access['datetime'] = pd.to_datetime(access['time'], format="%d/%b/%Y:%H:%M:%S", errors="coerce")
access.head()
# Out:
#          origin identity user                  time     tz type  \
# 0  64.242.88.10        -    -  07/Mar/2004:16:05:49  -0800  GET
# 1  64.242.88.10        -    -  07/Mar/2004:16:06:51  -0800  GET
# 2  64.242.88.10        -    -  07/Mar/2004:16:10:02  -0800  GET
# 3  64.242.88.10        -    -  07/Mar/2004:16:11:58  -0800  GET
# 4  64.242.88.10        -    -  07/Mar/2004:16:20:55  -0800  GET
#
#                                                  url      prot  status   size  \
# 0  /twiki/bin/edit/Main/Double_bounce_sender?topi...  HTTP/1.1     401  12846
# 1  /twiki/bin/rdiff/TWiki/NewUserTemplate?rev1=1....  HTTP/1.1     200   4523
# 2                       /mailman/listinfo/hsdivision  HTTP/1.1     200   6291
# 3                   /twiki/bin/view/TWiki/WikiSyntax  HTTP/1.1     200   7352
# 4                 /twiki/bin/view/Main/DCCAndPostFix  HTTP/1.1     200   5253
#
#              datetime
# 0 2004-03-07 16:05:49
# 1 2004-03-07 16:06:51
# 2 2004-03-07 16:10:02
# 3 2004-03-07 16:11:58
# 4 2004-03-07 16:20:55

# %%
access.dtypes
# Out:
# origin              object
# identity            object
# user                object
# time                object
# tz                  object
# type                object
# url                 object
# prot                object
# status               Int64
# size                 Int64
# datetime    datetime64[ns]
# dtype: object

# %%
access[access['size'].isnull()]
# Out:
#                                  origin identity user                  time  \
# 95    80-219-148-207.dclient.hispeed.ch        -    -  07/Mar/2004:19:47:36
# 342           68-174-110-154.nyc.rr.com        -    -  08/Mar/2004:05:38:57
# 366                       128.227.88.79        -    -  08/Mar/2004:06:57:46
# 420                          10.0.0.153        -    -  08/Mar/2004:08:32:24
# 422                          10.0.0.153        -    -  08/Mar/2004:08:32:27
# ...                                 ...      ...  ...                   ...
# 1436                         10.0.0.153        -    -  11/Mar/2004:15:52:37
# 1491                      145.253.208.9        -    -  12/Mar/2004:05:44:51
# 1496                         10.0.0.153        -    -  12/Mar/2004:11:01:26
# 1521                         10.0.0.153        -    -  12/Mar/2004:12:23:11
# 1531                         10.0.0.153        -    -  12/Mar/2004:12:23:40
#
#          tz     type                                              url  \
# 95    -0800  OPTIONS                                                *
# 342   -0800      GET                                      /razor.html
# 366   -0800      GET  /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif
# 420   -0800      GET                                                /
# 422   -0800      GET  /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif
# ...     ...      ...                                              ...
# 1436  -0800      GET                             /dccstats/index.html
# 1491  -0800      GET  /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif
# 1496  -0800      GET                                                /
# 1521  -0800      GET                                                /
# 1531  -0800      GET                             /dccstats/index.html
#
#           prot  status  size            datetime
# 95    HTTP/1.0     200  <NA> 2004-03-07 19:47:36
# 342   HTTP/1.1     304  <NA> 2004-03-08 05:38:57
# 366   HTTP/1.1     304  <NA> 2004-03-08 06:57:46
# 420   HTTP/1.1     304  <NA> 2004-03-08 08:32:24
# 422   HTTP/1.1     304  <NA> 2004-03-08 08:32:27
# ...        ...     ...   ...                 ...
# 1436  HTTP/1.1     304  <NA> 2004-03-11 15:52:37
# 1491  HTTP/1.1     304  <NA> 2004-03-12 05:44:51
# 1496  HTTP/1.1     304  <NA> 2004-03-12 11:01:26
# 1521  HTTP/1.1     304  <NA> 2004-03-12 12:23:11
# 1531  HTTP/1.1     304  <NA> 2004-03-12 12:23:40
#
# [139 rows x 11 columns]

# %% [markdown]
# ## Count the number of accesses (number of lines) made by an IP number

# %% [markdown]
# We use fancy indexing to filter from `access` only the rows where `origin` consists of an IP address. While an IP address consists of 4 numbers in the interval `[0,255]` separated by dots, a simpler regex suffices.

# %%
iponly = access[access['origin'].str.contains("^\d+\.\d+\.\d+\.\d+$")]
iponly.head()
# Out:
#          origin identity user                  time     tz type  \
# 0  64.242.88.10        -    -  07/Mar/2004:16:05:49  -0800  GET
# 1  64.242.88.10        -    -  07/Mar/2004:16:06:51  -0800  GET
# 2  64.242.88.10        -    -  07/Mar/2004:16:10:02  -0800  GET
# 3  64.242.88.10        -    -  07/Mar/2004:16:11:58  -0800  GET
# 4  64.242.88.10        -    -  07/Mar/2004:16:20:55  -0800  GET
#
#                                                  url      prot  status   size  \
# 0  /twiki/bin/edit/Main/Double_bounce_sender?topi...  HTTP/1.1     401  12846
# 1  /twiki/bin/rdiff/TWiki/NewUserTemplate?rev1=1....  HTTP/1.1     200   4523
# 2                       /mailman/listinfo/hsdivision  HTTP/1.1     200   6291
# 3                   /twiki/bin/view/TWiki/WikiSyntax  HTTP/1.1     200   7352
# 4                 /twiki/bin/view/Main/DCCAndPostFix  HTTP/1.1     200   5253
#
#              datetime
# 0 2004-03-07 16:05:49
# 1 2004-03-07 16:06:51
# 2 2004-03-07 16:10:02
# 3 2004-03-07 16:11:58
# 4 2004-03-07 16:20:55

# %% [markdown]
# Then we can group the rows with the same origin and count the size of each group

# %%
iponly.groupby('origin').size()
# Out:
# origin
# 10.0.0.153         270
# 12.22.207.235        1
# 128.227.88.79       14
# 142.27.64.35         7
# 145.253.208.9        7
# 194.151.73.43        4
# 195.11.231.210       1
# 195.230.181.122      1
# 195.246.13.119      12
# 200.222.33.33        1
# 203.147.138.233     13
# 207.195.59.160      20
# 208.247.148.12       4
# 212.21.228.26        1
# 212.92.37.62        14
# 213.181.81.4         1
# 216.139.185.45       1
# 219.95.17.51         1
# 4.37.97.186          1
# 61.165.64.6          4
# 61.9.4.61            3
# 64.242.88.10       452
# 64.246.94.141        1
# 64.246.94.152        1
# 66.213.206.2         1
# 67.131.107.5         3
# dtype: int64

# %% [markdown]
# ## Count the number of successful accesses (status 200) made by an IP number

# %% [markdown]
# We only have to filter the rows with status equal to 200

# %%
iponly[iponly['status'] == 200].count()
# Out:
# origin      627
# identity    627
# user        627
# time        627
# tz          627
# type        627
# url         627
# prot        627
# status      627
# size        627
# datetime    627
# dtype: int64

# %% [markdown]
# An alternative version uses the `len` function.

# %%
len(iponly[iponly['status'] == 200])
# Out:
# 627

# %% [markdown]
# ## Count the number of accesses for each directory served

# %% [markdown]
# We can extract the directory from the `url`, removing all characters after the last `/`.

# %% [markdown]
# First we add a column `dir` to each row

# %% [markdown]
# The first step is to build a function, called `extract_dir`, that computes the directory from a url.

# %%
def extract_dir(url):
    if re.search('/', url):
        return re.match('.*\/', url).group()
    else:
        return None

# %% [markdown]
# Since a regex can be a brittle solution, we have to check that it is actually correct. More precisely, we are going to check when the regex is not found.

# %%
access[~ access['url'].str.contains(".*\/")]
# Out:
#                                 origin identity user                  time  \
# 95   80-219-148-207.dclient.hispeed.ch        -    -  07/Mar/2004:19:47:36
# 906        h194n2fls308o1033.telia.com        -    -  09/Mar/2004:13:49:05
#
#         tz     type  url      prot  status  size            datetime
# 95   -0800  OPTIONS    *  HTTP/1.0     200  <NA> 2004-03-07 19:47:36
# 906  -0800       -"  408         -    <NA>  <NA> 2004-03-09 13:49:05

# %% [markdown]
# The first row is ok. The second one has been parsed incorrectly, since the combination of `type`, `url`, and `prot` is the single string `"-"` which does not contain a space. We have to decide whether to drop this row or to clean it.

# %%
# access.drop([906], inplace = True)
access.loc[906, 'status'] = int(access.loc[906, 'url'])
access[~ access['url'].str.contains(".*\/")]
# Out:
#                                 origin identity user                  time  \
# 95   80-219-148-207.dclient.hispeed.ch        -    -  07/Mar/2004:19:47:36
# 906        h194n2fls308o1033.telia.com        -    -  09/Mar/2004:13:49:05
#
#         tz     type  url      prot  status  size            datetime
# 95   -0800  OPTIONS    *  HTTP/1.0     200  <NA> 2004-03-07 19:47:36
# 906  -0800       -"  408         -     408  <NA> 2004-03-09 13:49:05

# %%
access[~ access['url'].str.contains(".*\/")]
# Out:
#                                 origin identity user                  time  \
# 95   80-219-148-207.dclient.hispeed.ch        -    -  07/Mar/2004:19:47:36
# 906        h194n2fls308o1033.telia.com        -    -  09/Mar/2004:13:49:05
#
#         tz     type  url      prot  status  size            datetime
# 95   -0800  OPTIONS    *  HTTP/1.0     200  <NA> 2004-03-07 19:47:36
# 906  -0800       -"  408         -     408  <NA> 2004-03-09 13:49:05

# %% [markdown]
# Then we can use `apply`

# %%
access['dir'] = access.apply(lambda row: extract_dir(row['url']), axis=1)
access.head()
# Out:
#          origin identity user                  time     tz type  \
# 0  64.242.88.10        -    -  07/Mar/2004:16:05:49  -0800  GET
# 1  64.242.88.10        -    -  07/Mar/2004:16:06:51  -0800  GET
# 2  64.242.88.10        -    -  07/Mar/2004:16:10:02  -0800  GET
# 3  64.242.88.10        -    -  07/Mar/2004:16:11:58  -0800  GET
# 4  64.242.88.10        -    -  07/Mar/2004:16:20:55  -0800  GET
#
#                                                  url      prot  status   size  \
# 0  /twiki/bin/edit/Main/Double_bounce_sender?topi...  HTTP/1.1     401  12846
# 1  /twiki/bin/rdiff/TWiki/NewUserTemplate?rev1=1....  HTTP/1.1     200   4523
# 2                       /mailman/listinfo/hsdivision  HTTP/1.1     200   6291
# 3                   /twiki/bin/view/TWiki/WikiSyntax  HTTP/1.1     200   7352
# 4                 /twiki/bin/view/Main/DCCAndPostFix  HTTP/1.1     200   5253
#
#              datetime                      dir
# 0 2004-03-07 16:05:49    /twiki/bin/edit/Main/
# 1 2004-03-07 16:06:51  /twiki/bin/rdiff/TWiki/
# 2 2004-03-07 16:10:02       /mailman/listinfo/
# 3 2004-03-07 16:11:58   /twiki/bin/view/TWiki/
# 4 2004-03-07 16:20:55    /twiki/bin/view/Main/

# %% [markdown]
# Since using the `axis` option of `apply` can be confusing, an alternative solution is to build a list correponding to the new column

# %%
access['dir2'] = access['url'].str.extract("(.*\/)")
access.head()
# Out:
#          origin identity user                  time     tz type  \
# 0  64.242.88.10        -    -  07/Mar/2004:16:05:49  -0800  GET
# 1  64.242.88.10        -    -  07/Mar/2004:16:06:51  -0800  GET
# 2  64.242.88.10        -    -  07/Mar/2004:16:10:02  -0800  GET
# 3  64.242.88.10        -    -  07/Mar/2004:16:11:58  -0800  GET
# 4  64.242.88.10        -    -  07/Mar/2004:16:20:55  -0800  GET
#
#                                                  url      prot  status   size  \
# 0  /twiki/bin/edit/Main/Double_bounce_sender?topi...  HTTP/1.1     401  12846
# 1  /twiki/bin/rdiff/TWiki/NewUserTemplate?rev1=1....  HTTP/1.1     200   4523
# 2                       /mailman/listinfo/hsdivision  HTTP/1.1     200   6291
# 3                   /twiki/bin/view/TWiki/WikiSyntax  HTTP/1.1     200   7352
# 4                 /twiki/bin/view/Main/DCCAndPostFix  HTTP/1.1     200   5253
#
#              datetime                      dir                     dir2
# 0 2004-03-07 16:05:49    /twiki/bin/edit/Main/    /twiki/bin/edit/Main/
# 1 2004-03-07 16:06:51  /twiki/bin/rdiff/TWiki/  /twiki/bin/rdiff/TWiki/
# 2 2004-03-07 16:10:02       /mailman/listinfo/       /mailman/listinfo/
# 3 2004-03-07 16:11:58   /twiki/bin/view/TWiki/   /twiki/bin/view/TWiki/
# 4 2004-03-07 16:20:55    /twiki/bin/view/Main/    /twiki/bin/view/Main/

# %% [markdown]
# ## For each origin, count the number of successful accesses

# %%
access[access['status'] == 200].groupby('origin').size()
# Out:
# origin
# 0x503e4fce.virnxx2.adsl-dhcp.tele.dk      2
# 1-320.cnc.bc.ca                           4
# 1-729.cnc.bc.ca                           6
# 10.0.0.153                              187
# 12.22.207.235                             1
#                                        ...
# watchguard.cgmatane.qc.ca                 2
# wc03.mtnk.rnc.net.cable.rogers.com        1
# wc09.mtnk.rnc.net.cable.rogers.com        3
# wwwcache.lanl.gov                         1
# yongsan-cache.korea.army.mil              4
# Length: 168, dtype: int64

# %% [markdown]
# ## For each origin, count the number of unsuccessful accesses, split according to the status code

# %% [markdown]
# The `groupby` can receive a list of column names

# %%
access[access['status'] != 200].groupby(['origin', 'status']).size()
# Out:
# origin                                 status
# 0x503e4fce.virnxx2.adsl-dhcp.tele.dk   304         1
# 1-729.cnc.bc.ca                        302         1
# 10.0.0.153                             302         1
#                                        304        82
# 128.227.88.79                          304         2
# 142.27.64.35                           302         1
#                                        304         4
# 145.253.208.9                          304         1
# 1513.cps.virtua.com.br                 404         1
# 195.246.13.119                         401         1
# 2-110.cnc.bc.ca                        304         3
# 207.195.59.160                         304         5
#                                        401         1
# 61.9.4.61                              404         2
# 64.242.88.10                           401       112
# 68-174-110-154.nyc.rr.com              304         1
# 92-moc-6.acn.waw.pl                    304         1
# cpe-203-51-137-224.vic.bigpond.net.au  302         1
# cr020r01-3.sac.overture.com            401         6
# h194n2fls308o1033.telia.com            408         1
# h24-70-56-49.ca.shawcable.net          404         1
# h24-71-236-129.ca.shawcable.net        302         1
#                                        304        15
# jacksonproject.cnc.bc.ca               302         1
#                                        304         1
# lj1160.inktomisearch.com               304         1
# mail.geovariances.fr                   304         9
# market-mail.panduit.com                401         1
# ogw.netinfo.bg                         304         8
# osdlab.eic.nctu.edu.tw                 404         1
# p213.54.168.132.tisdip.tiscali.de      401         1
# prxint-sxb3.e-i.net                    401         1
# spot.nnacorp.com                       304         1
# ts05-ip44.hevanet.com                  304         2
# dtype: int64

# %% [markdown]
# ## From the results of the previous point, add a column with the error class (the first digit of the status code)

# %%
grouped = access[access['status'] != 200].groupby(['origin', 'status']).size()
grouped.index
# Out:
# MultiIndex([( '0x503e4fce.virnxx2.adsl-dhcp.tele.dk', 304),
#             (                      '1-729.cnc.bc.ca', 302),
#             (                           '10.0.0.153', 302),
#             (                           '10.0.0.153', 304),
#             (                        '128.227.88.79', 304),
#             (                         '142.27.64.35', 302),
#             (                         '142.27.64.35', 304),
#             (                        '145.253.208.9', 304),
#             (               '1513.cps.virtua.com.br', 404),
#             (                       '195.246.13.119', 401),
#             (                      '2-110.cnc.bc.ca', 304),
#             (                       '207.195.59.160', 304),
#             (                       '207.195.59.160', 401),
#             (                            '61.9.4.61', 404),
#             (                         '64.242.88.10', 401),
#             (            '68-174-110-154.nyc.rr.com', 304),
#             (                  '92-moc-6.acn.waw.pl', 304),
#             ('cpe-203-51-137-224.vic.bigpond.net.au', 302),
#             (          'cr020r01-3.sac.overture.com', 401),
#             (          'h194n2fls308o1033.telia.com', 408),
#             (        'h24-70-56-49.ca.shawcable.net', 404),
#             (      'h24-71-236-129.ca.shawcable.net', 302),
#             (      'h24-71-236-129.ca.shawcable.net', 304),
#             (             'jacksonproject.cnc.bc.ca', 302),
#             (             'jacksonproject.cnc.bc.ca', 304),
#             (             'lj1160.inktomisearch.com', 304),
#             (                 'mail.geovariances.fr', 304),
#             (              'market-mail.panduit.com', 401),
#             (                       'ogw.netinfo.bg', 304),
#             (               'osdlab.eic.nctu.edu.tw', 404),
#             (    'p213.54.168.132.tisdip.tiscali.de', 401),
#             (                  'prxint-sxb3.e-i.net', 401),
#             (                     'spot.nnacorp.com', 304),
#             (                'ts05-ip44.hevanet.com', 304)],
#            names=['origin', 'status'])

# %% [markdown]
# Since the `status` field is part of the index, we have to move it to a column name, via `reset_index`

# %%
table = grouped.reset_index()
table.head()
# Out:
#                                  origin  status   0
# 0  0x503e4fce.virnxx2.adsl-dhcp.tele.dk     304   1
# 1                       1-729.cnc.bc.ca     302   1
# 2                            10.0.0.153     302   1
# 3                            10.0.0.153     304  82
# 4                         128.227.88.79     304   2

# %% [markdown]
# Now we can add the desired column

# %%
table['class'] = table['status'] // 100
table
# Out:
#                                    origin  status    0  class
# 0    0x503e4fce.virnxx2.adsl-dhcp.tele.dk     304    1      3
# 1                         1-729.cnc.bc.ca     302    1      3
# 2                              10.0.0.153     302    1      3
# 3                              10.0.0.153     304   82      3
# 4                           128.227.88.79     304    2      3
# 5                            142.27.64.35     302    1      3
# 6                            142.27.64.35     304    4      3
# 7                           145.253.208.9     304    1      3
# 8                  1513.cps.virtua.com.br     404    1      4
# 9                          195.246.13.119     401    1      4
# 10                        2-110.cnc.bc.ca     304    3      3
# 11                         207.195.59.160     304    5      3
# 12                         207.195.59.160     401    1      4
# 13                              61.9.4.61     404    2      4
# 14                           64.242.88.10     401  112      4
# 15              68-174-110-154.nyc.rr.com     304    1      3
# 16                    92-moc-6.acn.waw.pl     304    1      3
# 17  cpe-203-51-137-224.vic.bigpond.net.au     302    1      3
# 18            cr020r01-3.sac.overture.com     401    6      4
# 19            h194n2fls308o1033.telia.com     408    1      4
# 20          h24-70-56-49.ca.shawcable.net     404    1      4
# 21        h24-71-236-129.ca.shawcable.net     302    1      3
# 22        h24-71-236-129.ca.shawcable.net     304   15      3
# 23               jacksonproject.cnc.bc.ca     302    1      3
# 24               jacksonproject.cnc.bc.ca     304    1      3
# 25               lj1160.inktomisearch.com     304    1      3
# 26                   mail.geovariances.fr     304    9      3
# 27                market-mail.panduit.com     401    1      4
# 28                         ogw.netinfo.bg     304    8      3
# 29                 osdlab.eic.nctu.edu.tw     404    1      4
# 30      p213.54.168.132.tisdip.tiscali.de     401    1      4
# 31                    prxint-sxb3.e-i.net     401    1      4
# 32                       spot.nnacorp.com     304    1      3
# 33                  ts05-ip44.hevanet.com     304    2      3

# %% [markdown]
# If we want the class to be an integer, we need to apply also the `int` function

# %%
table['class'] = table['status'].apply(lambda row: int(row // 100))
table
# Out:
#                                    origin  status    0  class
# 0    0x503e4fce.virnxx2.adsl-dhcp.tele.dk     304    1      3
# 1                         1-729.cnc.bc.ca     302    1      3
# 2                              10.0.0.153     302    1      3
# 3                              10.0.0.153     304   82      3
# 4                           128.227.88.79     304    2      3
# 5                            142.27.64.35     302    1      3
# 6                            142.27.64.35     304    4      3
# 7                           145.253.208.9     304    1      3
# 8                  1513.cps.virtua.com.br     404    1      4
# 9                          195.246.13.119     401    1      4
# 10                        2-110.cnc.bc.ca     304    3      3
# 11                         207.195.59.160     304    5      3
# 12                         207.195.59.160     401    1      4
# 13                              61.9.4.61     404    2      4
# 14                           64.242.88.10     401  112      4
# 15              68-174-110-154.nyc.rr.com     304    1      3
# 16                    92-moc-6.acn.waw.pl     304    1      3
# 17  cpe-203-51-137-224.vic.bigpond.net.au     302    1      3
# 18            cr020r01-3.sac.overture.com     401    6      4
# 19            h194n2fls308o1033.telia.com     408    1      4
# 20          h24-70-56-49.ca.shawcable.net     404    1      4
# 21        h24-71-236-129.ca.shawcable.net     302    1      3
# 22        h24-71-236-129.ca.shawcable.net     304   15      3
# 23               jacksonproject.cnc.bc.ca     302    1      3
# 24               jacksonproject.cnc.bc.ca     304    1      3
# 25               lj1160.inktomisearch.com     304    1      3
# 26                   mail.geovariances.fr     304    9      3
# 27                market-mail.panduit.com     401    1      4
# 28                         ogw.netinfo.bg     304    8      3
# 29                 osdlab.eic.nctu.edu.tw     404    1      4
# 30      p213.54.168.132.tisdip.tiscali.de     401    1      4
# 31                    prxint-sxb3.e-i.net     401    1      4
# 32                       spot.nnacorp.com     304    1      3
# 33                  ts05-ip44.hevanet.com     304    2      3

# %% [markdown]
# ## Cluster the accesses in 5-minutes time slices (e.g. from 14:00 to 14:05, from 14:05 to 14:10, etc). Count the number of accesses for each time slice

# %% [markdown]
# We use a procedure similar to the previous point. Notice that we need only the hour and the minute (not the full timestamp) to build the clusters.

# %%
access['cluster'] = (access['datetime'].dt.hour * 60 + access['datetime'].dt.minute) // 5
